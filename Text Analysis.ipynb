# %% [markdown]
# # Text Analysis

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import regex as re 
from os import listdir
from os.path import isfile, join
import json 
# get files in directory 
onlyfiles = [f for f in listdir("wiki_content") if isfile(join("wiki_content", f))]

with open('inv_science_name_dict.json', 'r', encoding = 'utf-8') as f: 
    science_dict = json.load(f)

# %% [markdown]
# # Scrape content
#
# Get only the content of the Wikipages, instead of all of the reference stuff, initial headers, hyperlinks, and other noisy things.

# %%
def get_wiki(_page, get_txt = False):
    baseurl = "https://en.wikipedia.org/w/api.php?"
    action = "action=query"
    title = f"titles={_page}"
    content = "prop=extracts&exlimit=1&explaintext" # this is different than before! 
    dataformat ="format=json"
    
    query = "{}{}&{}&{}&{}".format(baseurl, action, content, title, dataformat)
    print(query)
    
    if get_txt == True:
        resp = requests.get(query).json()
        page_id = [i for i in resp['query']['pages'].keys()][0] # get page id
        txt = resp['query']['pages'][page_id]['extract']
        return txt
    else:
        return requests.get(query).json()

# %%
name_req = [file.split('.txt')[0] for file in onlyfiles]  

''' Scrape the pages '''
for node in name_req:
    txt = get_wiki(node, get_txt=True)
    
    with open(f'wiki_txt/{node}.txt', 'w', encoding = 'utf-8') as f:
        f.write(txt)
# Out:
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=A._Doak_Barnett&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=A._F._K._Organski&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=A._H._J._Prins&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=A._L._Kroeber&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=A._Ronald_Gallant&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Aaron_Antonovsky&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Aaron_Belkin&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Aaron_Cicourel&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Aaron_Wildavsky&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Abba_P._Lerner&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Abdelkebir_Khatibi&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Abdellah_Hammoudi&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Abdul_Razzaq_Kemal&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Abhijit_Banerjee&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Abraham_Maslow&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Abraham_Moles&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Abraham_Robinson&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Abu_Zayd_al-Balkhi&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Adair_Turner,_Baron_Turner_of_Ecchinswell&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Adam_Berinsky&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Adam_Kuper&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Adam_Possamai&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Adam_Przeworski&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Adam_Smith&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Adelbert_Ames_Jr.&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Adeolu_Akande&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Adil_Abdul-Mahdi&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Adolf_A._Berle&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Adolphe_Quetelet&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Adolphus_G._Belk_Jr.&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Adolph_Wagner&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Adriana_Kugler&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Adrian_Furnham&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Adria_Lawrence&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Afanasy_Shchapov&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Agustin_Cueva&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Agustín_Carstens&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Ahron_Bregman&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Aihwa_Ong&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Ajay_Chhibber&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Ajit_Ranade&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Akiyoshi_Kitaoka&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alain_Ehrenberg&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alain_Touraine&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alan_Abramowitz&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alan_Baddeley&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alan_Blinder&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alan_Bock&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alan_Budd&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alan_E._Kazdin&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alan_Greenspan&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alan_Macfarlane&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alan_Manning&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alan_S._Kaufman&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alan_Walters&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alasdair_Smith&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alberto_Alesina&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Albert_Bandura&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Albert_Benschop&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Albert_Bergstrom&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Albert_Buell_Lewis&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Albert_Ellis&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Albert_J._Meyer_(economist)&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Albert_Nalchajyan&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Albert_Schäffle&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Albion_Woodbury_Small&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alcira_Argumedo&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alejandro_Portes&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alejandro_Toledo&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Aleksandr_Kapto&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Ales_Hrdlicka&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alexander_Deichsel&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alexander_Luria&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alexander_Sachs&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alexander_Tarasov&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alexander_Van_der_Bellen&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alexander_Wendt&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alexis_de_Tocqueville&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alex_Tabarrok&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alfons_Vansteenwegen&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alfredo_Castillero_Hoyos&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alfred_Adler&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alfred_Binet&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alfred_D._Chandler_Jr.&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alfred_E._Johnson&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alfred_Eichner&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alfred_Gell&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alfred_H._Conrad&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alfred_Jules_Émile_Fouillée&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alfred_Marshall&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alfred_Mitchell-Innes&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alfred_R._Lindesmith&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alfred_Radcliffe-Brown&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alfred_Schütz&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alfred_Stepan&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alfred_Vierkandt&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alfred_Weber&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alice_Beck_Kehoe&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alice_Kang&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alice_Miller_(psychologist)&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alice_Rivlin&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alison_Dagnes&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Ali_Babacan&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Ali_ibn_Sahl_Rabban_al-Tabari&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Ali_M._El-Agraa&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Ali_Shariati&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Allan_Paivio&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Allan_Schnaiberg&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Allison_Stanger&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Allyn_Abbott_Young&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alon_Ben-Meir&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Aloysius-Michaels_Nnabugwu_Okolie&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alva_Myrdal&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alvin_E._Roth&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alvin_Gouldner&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alvin_Hansen&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alvin_Wolfe&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Alwyn_Young&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Amartya_Sen&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Amelia_Fletcher&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Amin_Maalouf&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Amitai_Etzioni&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Ammar_Bouhouche&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Amos_Tversky&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Amrita_Basu&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Amrita_Narlikar&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Amy_Finkelstein&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Amy_Gutmann&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Amy_Mazur&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Amy_Singer&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Anatoly_Khazanov&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Andreas_Löschel&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Andrei_Shleifer&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Andrew_Arato&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Andrew_Bacevich&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Andrew_Greeley&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Andrew_Hughes_Hallett&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Andrew_Lo&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Andrew_Milner&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Andrew_Moravcsik&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Andrew_N._Meltzoff&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Andrew_Oswald&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Andrew_Pickering&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Andrew_Sentance&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Andrey_Korotayev&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Andre_Beteille&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Andre_Gunder_Frank&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Andrzej_Sławiński&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Andrés_Molina_Enríquez&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Angus_Deaton&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Aninhalli_Vasavi&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Ankur_Pare&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Anna_Freud&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Anna_Gifty_Opoku-Agyeman&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Anna_Grzymala&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Anna_J._Cooper&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Anna_Schwartz&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Anne-Marie_Slaughter&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Annette_Baker_Fox&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Anne_C._Petersen&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Anne_Carter_(economist)&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Anne_Osborn_Krueger&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Anne_Robert_Jacques_Turgot&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Anne_Treisman&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Annie_Marion_MacLean&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Ann_Dunham&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Ann_Mische&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Ann_Swidler&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Anselm_Strauss&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Anson_D._Shupe&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Anthony_Downs&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Anthony_F._C._Wallace&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Anthony_Giddens&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Anthony_Ludovici&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Anthony_Saunders&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Anthony_Venables&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Antoaneta_Vassileva&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Antoine_Augustin_Cournot&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Antonina_Kłoskowska&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Antonio_Caso_Andrade&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Antonio_Gramsci&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Antonio_Negri&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Antoni_Kępiński&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Antony_Davies&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Anton_Blok&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=António_de_Oliveira_Salazar&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Anu_Muhammad&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Anuška_Ferligoj&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Anwar_Shaikh_(economist)&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Aníbal_Cavaco_Silva&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Aníbal_Quijano&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Aquila_Berlas_Kiani&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Archon_Fung&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Arend_Lijphart&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Ariel_Rubinstein&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Aristotle&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Arjun_Appadurai&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Arlie_Russell_Hochschild&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Armando_Di_Filippo&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Armand_Peschard-Sverdrup&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Armen_Alchian&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Armindo_Freitas-Magalhães&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Armin_Falk&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Arne_Runeberg&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Arnold_Gehlen&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Arnold_Harberger&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Arnold_Marshall_Rose&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Arnold_Mindell&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Arnold_Plant&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Arnold_Wolfers&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Arnold_Zellner&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Aron_K._Barbey&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Arthur_Cecil_Pigou&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Arthur_F._Bentley&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Arthur_J._Bachrach&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Arthur_Jensen&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Arthur_Kornhauser&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Arthur_Laffer&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Arthur_Lewbel&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Arthur_Maurice_Hocart&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Arthur_Melvin_Okun&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Arthur_Naftalin&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Arthur_Salz&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Arthur_Seldon&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Arthur_Young_(agriculturist)&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Arturo_Escobar_(anthropologist)&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Arturo_Porzecanski&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Artyom_Shneyerov&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Arun_Agrawal&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Arun_Sundararajan&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=As'ad_AbuKhalil&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Asher_Arian&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Asher_Cohen&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Asher_Tishler&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Ashis_Nandy&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Ashley_E._Jardina&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Ashley_Montagu&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Assar_Lindbeck&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Atilla_Yayla&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Attahiru_Jega&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Attilio_Celant&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Audrey_Richards&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Auguste_Comte&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Augustus_John_Rush&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=August_Friedrich_Wilhelm_Crome&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Austan_Goolsbee&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Austin_Robinson&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Austin_Sarat&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Aušra_Augustinavičiūtė&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Averil_Leimon&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Averroes&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Aviad_Raz&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Avinash_Dixit&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Avishay_Braverman&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Axel_Honneth&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Axel_Leijonhufvud&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Ayesha_Jalal&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=B._Anthony_Bogues&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=B._F._Skinner&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=B._R._Ambedkar&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Baidyanath_Misra&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Barbara_Bergmann&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Barbara_Bonner&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Barbara_Fredrickson&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Barbara_Geddes&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Barbara_J._Spencer&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Barbara_Rothbaum&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Barney_Glaser&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Barrington_Moore_Jr.&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Barry_B._Levine&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Barry_Bluestone&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Barry_Eichengreen&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Barry_Glassner&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Barry_Wellman&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Baruch_Kimmerling&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Basil_Yamey&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Beatrice_Webb&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Beatrice_Weder_di_Mauro&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Beatriz_Magaloni&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Benedict_Anderson&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Bengt_Holmström&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Benjamin_Barber&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Benjamin_Cohen_(political_economist)&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Benjamin_Diokno&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Benjamin_Ginsberg_(political_scientist)&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Benjamin_Graham&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Benjamin_Lee_Whorf&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Benjamin_M._Friedman&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Benjamin_Strong_Jr.&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Benjamin_Zablocki&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Bennett_McCallum&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Benton_Johnson&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Ben_Bernanke&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Ben_Kerkvliet&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Bernardo_Kliksberg&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Bernardo_Sorj&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Bernard_Lonergan&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Bernard_van_Praag&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Bernie_Fraser_(economist)&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Bertell_Ollman&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Bertil_Ohlin&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Bertram_Gawronski&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Bertrand_de_Jouvenel&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Bethany_Albertson&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Bethany_Barratt&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Beth_A._Simmons&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Betty_Glad&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Bibb_Latané&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Bill_Avery&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Bill_Irons&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Bill_O'Hanlon&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Bindeshwar_Pathak&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Bingu_wa_Mutharika&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Bluma_Zeigarnik&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Boaventura_de_Sousa_Santos&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Bogdan_Denitch&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Bohdan_Hawrylyshyn&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Bolaji_Akinyemi&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Boris_Kagarlitsky&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Boyan_Jovanovic&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Brad_W._Setser&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Branko_Horvat&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Brendan_O'Leary&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Brenda_Milner&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Brent_Berlin&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Brian_Butterworth&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Brian_Knutson&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Brian_Massumi&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Brian_Wesbury&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Brigitte_L._Nacos&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Bronisław_Malinowski&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Bronisław_Piłsudski&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Brooke_Ackerly&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Bruce_A._Williams&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Bruce_Bueno_de_Mesquita&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Bruce_Hood_(psychologist)&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Bruce_Kingma&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Bruce_Trigger&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Bruno_Frey&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Bruno_Latour&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Bryan_Caplan&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Bryan_Turner_(sociologist)&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Buell_Quain&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Burton_Malkiel&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Burton_Weisbrod&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Bärbel_Inhelder&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=C._Arden_Pope&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=C._Christine_Fair&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=C._Fred_Bergsten&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=C._J._Pascoe&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=C._Lloyd_Morgan&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=C._M._Mayo&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=C._Scott_Littleton&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=C._Wright_Mills&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Calvin_Veltman&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Camilla_Wedgwood&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Campbell_Harvey&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Carleton_S._Coon&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Carlos_A._Vegh&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Carlos_Manuel_Urzúa_Macías&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Carlota_Perez&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Carl_Brigham&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Carl_Brinkmann&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Carl_E._Walsh&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Carl_J._Couch&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Carl_Jung&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Carl_Levy_(political_scientist)&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Carl_Menger&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Carl_R._May&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Carl_Rogers&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Carl_Stumpf&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Carmen_Reinhart&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Carole_Joffe&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Carolyn_Heinrich&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Carolyn_R._Payton&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Carol_Corrado&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Carol_Gilligan&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Carol_M._Swain&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Cary_Cooper&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Catharine_Cox_Miles&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Catherine_Berndt&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Catherine_Boone&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Catherine_L._Besteman&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Catherine_Tucker&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Cathryn_Clüver_Ashbrook&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Cathy_Small&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Cecilia_Rouse&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Cecil_R._Reynolds&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Celia_Stopnicka_Heller&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Celinda_Lake&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Celso_Furtado&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Chalmers_Johnson&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Chandrakala_A._Hate&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Chantal_Mouffe&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Charles_A._Holt&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Charles_Beitz&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Charles_Booth_(social_reformer)&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Charles_C._Ragin&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Charles_Cooley&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Charles_Davenant&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Charles_E._Osgood&format=json
# ...
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Walter_Benjamin&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Walter_Block&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Walter_Dean_Burnham&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Walter_Dill_Scott&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Walter_E._Williams&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Walter_F._Buckley&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Walter_K._Andersen&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Walter_Mischel&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Walter_Oi&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Walter_Truett_Anderson&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Walter_W._Powell&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Walt_Whitman_Rostow&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Warner_R._Schilling&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Warren_Coats&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Warren_Mosler&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Warwick_McKibbin&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Wassily_Leontief&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Werner_Sombart&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Wesley_Clair_Mitchell&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Wilhelm_Bleek&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Wilhelm_Dilthey&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Wilhelm_Grimm&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Wilhelm_Heitmeyer&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Wilhelm_Radloff&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Wilhelm_Schmidt_(linguist)&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Wilhelm_Wundt&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Willem_Buiter&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Willem_Somermeyer&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_A._Barnett&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_A._Darity_Jr.&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_A._Niskanen&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_Anderson_(political_scientist)&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_Antholis&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_Ashley_(economic_historian)&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_Baumol&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_Benoit&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_Beveridge&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_Blake_(economist)&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_Brainard&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_D._Berry_(political_scientist)&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_D._Clark&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_F._Sharpe&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_Fielding_Ogburn&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_Fleetwood&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_Foote_Whyte&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_Forster_Lloyd&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_G._Gale&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_Godwin&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_Graham_Sumner&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_H._Janeway&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_H._Riker&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_H._Sewell&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_H._Whyte&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_Hewins&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_Hsiao&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_I._Robinson&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_James&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_Jones_(philologist)&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_Julius_Wilson&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_K._Black&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_L._Breit&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_Labov&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_McDougall_(psychologist)&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_Nordhaus&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_Oakland&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_Ogilvie_of_Pittensear&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_Paterson_(banker)&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_Petty&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_Phillips_(economist)&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_Richard_Miller&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_Stanley_Jevons&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_Sturtevant&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_Swann&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_T._R._Fox&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_Thompson_(philosopher)&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_Vickrey&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=William_Wohlforth&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Willie_Pearson_Jr.&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Willmoore_Kendall&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Will_Herberg&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Will_Kymlicka&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Wolfgang_Köhler&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Wolfgang_Metzger&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Wolfgang_Pesendorfer&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Wolfgang_Schluchter&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Woodrow_Wilson&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Wu_Jinglian&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Władysław_Markiewicz&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Władysław_Witwicki&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Xavier_Gabaix&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Xavier_Sala-i-Martin&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Xavier_Vives&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Xenophon&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Xenophon_Zolotas&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Xiaokai_Yang&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Yadav_Pant&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Yair_Tauman&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Yanis_Varoufakis&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Yaprak_Gürsoy&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Yasmin_Jiwani&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Yasuma_Takada&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Yasunosuke_Gonda&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Yegor_Gaidar&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Yelyzaveta_Yasko&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Yew-Kwang_Ng&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Yolanda_Murphy&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Yongcheol_Shin&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Yoram_Barzel&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Yoram_Ben-Porat&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Yukon_Huang&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Yuri_Levada&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Yuri_Poluneev&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Yu_Guangyuan&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Yves_Zenou&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Yūjirō_Motora&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Zbigniew_Brzezinski&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Zeev_Maoz&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Zeev_Sternhell&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Zeine_Ould_Zeidane&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Zenon_Pylyshyn&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Zhang_Weiying&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Zhou_Xiaochuan&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Ziya_Gökalp&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Zoltan_Acs&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Zvi_Griliches&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Zygmunt_Bauman&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Ágnes_Heller&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Ásgeir_Helgason&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Élisabeth_Badinter&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Émile_Durkheim&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Émile_Littré&format=json
# https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&explaintext&titles=Émile_Poulat&format=json

# %%
# get files in directory 
onlyfiles = [f for f in listdir("wiki_txt") if isfile(join("wiki_txt", f))]

# %%
''' Extract links '''
sofie_dict = {}
for name, field in science_dict.items():
    try:
        file = name.replace(' ','_')
        with open(f'wiki_txt/{file}.txt','r', encoding = 'utf-8') as f:
            txt = f.read()
        sofie_dict.update({name:txt})
    except:
        pass
with open(f'sofie_dict.json','w', encoding = 'utf-8') as f:
    json.dump(sofie_dict, f)

# %% [markdown]
# ### Extract text and remove names of other social scientists

# %%
#  List of all the names 
all_names = [name.split('(')[0].strip() for name in science_dict.keys()]
all_names.extend([name.split(' ')[-1] for name in all_names]) # get the "last name" of the names 
sorted(all_names, key = len, reverse = False)[:5]

# %%
"(?:(?: ))?(?: |'s|')"

# %%
sorted(all_names, key = len, reverse = True)
# Out:
# ['Garry Runciman, 3rd Viscount Runciman of Doxford',
#  'Adair Turner, Baron Turner of Ecchinswell',
#  'Michael Young, Baron Young of Dartington',
#  'Nicholas Stern, Baron Stern of Brentford',
#  'Pierre Le Pesant, sieur de Boisguilbert',
#  'Philip Norton, Baron Norton of Louth',
#  'Mervyn King, Baron King of Lothbury',
#  'Pierre Guillaume Frédéric le Play',
#  'Aloysius-Michaels Nnabugwu Okolie',
#  'Sidney Webb, 1st Baron Passfield',
#  'Francisco Javier Carrillo Gamboa',
#  'Montagu Norman, 1st Baron Norman',
#  'Eric Roll, Baron Roll of Ipsden',
#  'Christoph von Fürer-Haimendorf',
#  'August Friedrich Wilhelm Crome',
#  'Sadie Tanner Mossell Alexander',
#  'William Ogilvie of Pittensear',
#  'Ali ibn Sahl Rabban al-Tabari',
#  'Muhammad ibn Zakariya al-Razi',
#  'Hannes Hólmsteinn Gissurarson',
#  'Jesús M. de Miguel Rodríguez',
#  'Elisabeth Altmann-Gottheiner',
#  'Charles Knickerbocker Harley',
#  'Maurice Peston, Baron Peston',
#  'Richard Layard, Baron Layard',
#  'Mohammad Najatuallah Siddiqi',
#  'Fernando Escalante Gonzalbo',
#  'Alfred Jules Émile Fouillée',
#  'António de Oliveira Salazar',
#  'Edward Lawrence Wheelwright',
#  'Gisela Bleibtreu-Ehrenberg',
#  'Boaventura de Sousa Santos',
#  'Eduardo Viveiros de Castro',
#  'Meghnad Desai, Baron Desai',
#  'Carlos Manuel Urzúa Macías',
#  'Johann Heinrich von Thünen',
#  'Anne Robert Jacques Turgot',
#  'Janet M. Box-Steffensmeier',
#  'Elmer Eric Schattschneider',
#  'Fernando Henrique Cardoso',
#  'Gerardo Reichel-Dolmatoff',
#  'Nicholas Georgescu-Roegen',
#  'Christopher A. Pissarides',
#  'Armindo Freitas-Magalhães',
#  'Rachel and Stephen Kaplan',
#  'Pierre L. van den Berghe',
#  'Georgi Dimitrov Dimitrov',
#  'Charlotte Perkins Gilman',
#  'Arlie Russell Hochschild',
#  'Roberto Mangabeira Unger',
#  'Oswald von Nell-Breuning',
#  'Henry James Sumner Maine',
#  'Marjorie Harness Goodwin',
#  'Nicholas Miklouho-Maclay',
#  'Florence Connolly Shipek',
#  'Qazi Kholiquzzaman Ahmad',
#  'Antoine Augustin Cournot',
#  'Francis Ysidro Edgeworth',
#  'Terence Wilmot Hutchison',
#  'Anna Gifty Opoku-Agyeman',
#  'Chris William Sanchirico',
#  'Mikhail Tugan-Baranovsky',
#  'Alexander Van der Bellen',
#  'Ahmed ibn Sahl al-Balkhi',
#  'Magdalen Dorothea Vernon',
#  'John Alexander Armstrong',
#  'Kathleen Cordelia Bailey',
#  'Alfredo Castillero Hoyos',
#  'Satyabrata Rai Chowdhuri',
#  'Sara McLaughlin Mitchell',
#  'Armand Peschard-Sverdrup',
#  'Cheryl Schonhardt-Bailey',
#  'Valeria Sinclair-Chapman',
#  'Reeta Chowdhari Tremblay',
#  'Franklin Henry Giddings',
#  'Eugenio María de Hostos',
#  'Robert Morrison MacIver',
#  'Daniel Patrick Moynihan',
#  'Ricardo Pozas Arciniega',
#  'Eugen Rosenstock-Huessy',
#  'Thomas Patrick Thompson',
#  'William Fielding Ogburn',
#  'George-Marios Angeletos',
#  'Gloria Macapagal Arroyo',
#  'Hermann Heinrich Gossen',
#  'Stephany Griffith-Jones',
#  'Clyde V. Prestowitz Jr.',
#  'Rogelio Ramírez de la O',
#  'Diego Abad de Santillán',
#  'Beatrice Weder di Mauro',
#  'María del Carmen Guisán',
#  'Mihaly Csikszentmihalyi',
#  'Gustav Adolf Wohlgemuth',
#  'Bruce Bueno de Mesquita',
#  'Cathryn Clüver Ashbrook',
#  'Claudia López Hernández',
#  'Richard Fritz Behrendt',
#  'Christopher Chase-Dunn',
#  'Shmuel Noah Eisenstadt',
#  'Celia Stopnicka Heller',
#  'Frederick B. Lindstrom',
#  'Donald Angus MacKenzie',
#  'Pierre-Joseph Proudhon',
#  'France Winddance Twine',
#  'Andrés Molina Enríquez',
#  'Alfred Radcliffe-Brown',
#  'Mary Catherine Bateson',
#  'Frank Hamilton Cushing',
#  'Mary Lindsay Elmendorf',
#  'Montek Singh Ahluwalia',
#  'Debapriya Bhattacharya',
#  'Lawrence J. Christiano',
#  'John Kenneth Galbraith',
#  'William Stanley Jevons',
#  'Manuela Ferreira Leite',
#  'Jason Gaverick Matheny',
#  'Francis William Newman',
#  'Javier Perez-Capdevila',
#  'Alfred D. Chandler Jr.',
#  'George W. Stocking Sr.',
#  'Aušra Augustinavičiūtė',
#  'Marie-Louise von Franz',
#  'George Armitage Miller',
#  'William Richard Miller',
#  'J. Buzz Von Ornsteiner',
#  'Sharon Thompson-Schill',
#  'Margaret Floy Washburn',
#  'Walter Truett Anderson',
#  'Mounia Bennani-Chraïbi',
#  'Mizanur Rahman Shelley',
#  'Susanne Hoeber Rudolph',
#  'Matthew Søberg Shugart',
#  'Tijjani Muhammad-Bande',
#  'Jean-Michel Berthelot',
#  'Cornelius Castoriadis',
#  'Patricia Hill Collins',
#  'Donatella della Porta',
#  'Crystal Marie Fleming',
#  'Danièle Hervieu-Léger',
#  'Irving Louis Horowitz',
#  'Frank Lancaster Jones',
#  'Seymour Martin Lipset',
#  'Robert Staughton Lynd',
#  'Jean-François Lyotard',
#  'Jean-Jacques Rousseau',
#  'Peter Robert Saunders',
#  'Ferdinand de Saussure',
#  'Albion Woodbury Small',
#  'William Graham Sumner',
#  'Alexis de Tocqueville',
#  'William Julius Wilson',
#  'René Zavaleta Mercado',
#  'Gøsta Esping-Andersen',
#  'Thomas Robert Malthus',
#  'Catherine L. Besteman',
#  'Edmund Snow Carpenter',
#  'Elizabeth Cullen Dunn',
#  'E. E. Evans-Pritchard',
#  'Arthur Maurice Hocart',
#  'Charles Miller Leslie',
#  'Horace Mitchell Miner',
#  'Anthony F. C. Wallace',
#  'Lee Henderson Watkins',
#  'Conrad Phillip Kottak',
#  'Nancy Oestreich Lurie',
#  'Graciela Chichilnisky',
#  'Jean-Baptiste Colbert',
#  'Michael James Farrell',
#  'Andrew Hughes Hallett',
#  'Peter Reinhard Hansen',
#  'Narayana Kocherlakota',
#  'Frederic Sterling Lee',
#  'William Forster Lloyd',
#  'Henry Dunning Macleod',
#  'Alfred Mitchell-Innes',
#  'Giancarlo Pallavicini',
#  'Johann Karl Rodbertus',
#  'Gopal Krishna Sarangi',
#  'Nassau William Senior',
#  'Christopher Thornberg',
#  'Michael Dean Woodford',
#  'Eugen von Böhm-Bawerk',
#  'William A. Darity Jr.',
#  'Larry Hsien Ping Lang',
#  'John Ramsay McCulloch',
#  'Wesley Clair Mitchell',
#  'John William Atkinson',
#  'Hermann von Helmholtz',
#  'Stanley Smith Stevens',
#  'Elisabeth Kübler-Ross',
#  'Lincoln P. Bloomfield',
#  'Jean-Charles de Borda',
#  'Clarissa Rile Hayward',
#  'Joanna Marszałek-Kawa',
#  'Emilia Justyna Powell',
#  'Elizabeth Zechmeister',
#  'Jeffrey C. Alexander',
#  'James Samuel Coleman',
#  'Susan Myra Kingsbury',
#  'Alfred R. Lindesmith',
#  'Annie Marion MacLean',
#  'Bronisław Malinowski',
#  'Władysław Markiewicz',
#  'José Ortega y Gasset',
#  'Jean-Claude Passeron',
#  'Arnold Marshall Rose',
#  'Charles E. Silberman',
#  'Edward Burnett Tylor',
#  'George Edgar Vincent',
#  'Immanuel Wallerstein',
#  'Edmund Wnuk-Lipinski',
#  'Antonio Caso Andrade',
#  'Marquis de Condorcet',
#  'Barrington Moore Jr.',
#  'Henri de Saint-Simon',
#  'Christian Bromberger',
#  'Malcolm Carr Collier',
#  'Phillip Harold Lewis',
#  'Michael Atwood Mason',
#  'Gananath Obeyesekere',
#  'Hortense Powdermaker',
#  'Robert A. Rubinstein',
#  'Nancy Scheper-Hughes',
#  'Karl Hermann Berendt',
#  'Leonardo Auernheimer',
#  'Robert Dudley Baxter',
#  'Ricardo J. Caballero',
#  'John Elliott Cairnes',
#  'Benjamin M. Friedman',
#  'Pierangelo Garegnani',
#  'Jose Antonio Gomariz',
#  'Christian Gouriéroux',
#  'Harry Gordon Johnson',
#  'Jean-Jacques Laffont',
#  'Xavier Sala-i-Martin',
#  'Sendhil Mullainathan',
#  'Karthik Muralidharan',
#  'John Forbes Nash Jr.',
#  'Manuel V. Pangilinan',
#  'Wolfgang Pesendorfer',
#  'Peter C. B. Phillips',
#  'Jean-Pierre Ponssard',
#  'Frank-Jürgen Richter',
#  'Christoph M. Schmidt',
#  'Gustav von Schmoller',
#  'Stephan Schulmeister',
#  'Edwin R. A. Seligman',
#  'Hugo F. Sonnenschein',
#  'Henry Charles Taylor',
#  'Paul Schuster Taylor',
#  'Friedrich von Wieser',
#  'Oliver E. Williamson',
#  'Clarence Edwin Ayres',
#  'John Robert Anderson',
#  'Dermot Barnes-Holmes',
#  'Lisa Feldman Barrett',
#  'Lawrence W. Barsalou',
#  'James McKeen Cattell',
#  'Hans-Werner Gessmann',
#  'Kay Redfield Jamison',
#  'Philip Johnson-Laird',
#  'Jagannath Prasad Das',
#  'George Trumbull Ladd',
#  'Sally-Anne McCormack',
#  'Jacques-Alain Miller',
#  'Charles Samuel Myers',
#  'Christopher Peterson',
#  'Harry Stack Sullivan',
#  'Alfons Vansteenwegen',
#  'Ernst Heinrich Weber',
#  'Louis Leon Thurstone',
#  'Stephen Ansolabehere',
#  'Sharon Wright Austin',
#  'Adolphus G. Belk Jr.',
#  'Thomas J. Biersteker',
#  'Jean Bethke Elshtain',
#  'Harold Foote Gosnell',
#  'Samuel P. Huntington',
#  'Bertrand de Jouvenel',
#  'Sebastián L. Mazzuca',
#  'Kay Lehman Schlozman',
#  'Mitchell A. Seligson',
#  'Anne-Marie Slaughter',
#  'Patricia A. Weitsman',
#  'Thomas P. M. Barnett',
#  'Peter J. Katzenstein',
#  'Julieta Castellanos',
#  'Marshall B. Clinard',
#  'Dankwart Danckwerts',
#  'Régis Dericquebourg',
#  'Florestan Fernandes',
#  'John Bellamy Foster',
#  'Chandrakala A. Hate',
#  'Aquila Berlas Kiani',
#  'Antonina Kłoskowska',
#  'Eugene M. Kulischer',
#  'Claude Lévi-Strauss',
#  'José María Maravall',
#  'Everett Dean Martin',
#  'Vladimir Martynenko',
#  'George Herbert Mead',
#  'James D. Montgomery',
#  'Radhakamal Mukerjee',
#  'Jacqueline Peschard',
#  'William I. Robinson',
#  'Kurt C. Schlichting',
#  'Wolfgang Schluchter',
#  'Rodolfo Stavenhagen',
#  'William Foote Whyte',
#  'Christopher Winship',
#  'Mary Wollstonecraft',
#  'Tatyana Zaslavskaya',
#  'Nicholas Christakis',
#  'Raymond J. DeMallie',
#  'Raymond D. Fogelson',
#  'Richard Borshay Lee',
#  'Erland Nordenskiöld',
#  'Elsie Clews Parsons',
#  'Thomas J. Pluckhahn',
#  'James George Frazer',
#  'Bronisław Piłsudski',
#  'Sidney S. Alexander',
#  'Kenneth E. Boulding',
#  'Markus Brunnermeier',
#  'Henry Charles Carey',
#  'Neil W. Chamberlain',
#  'Steven N. S. Cheung',
#  'Nicolaus Copernicus',
#  'Mathias Dewatripont',
#  'Christopher Freeman',
#  'Daniel S. Hamermesh',
#  'David Forbes Hendry',
#  'Lewis Webster Jones',
#  'John Maynard Keynes',
#  'Anne Osborn Krueger',
#  'Stanislav Menshikov',
#  'Gustave de Molinari',
#  'William A. Niskanen',
#  'Ngozi Okonjo-Iweala',
#  'Philippe Van Parijs',
#  'Lasse Heje Pedersen',
#  'Donald John Roberts',
#  'Walt Whitman Rostow',
#  'Justinian Rweyemamu',
#  'Fabrizio Saccomanni',
#  'Aníbal Cavaco Silva',
#  'Christopher A. Sims',
#  'Stanislav Strumilin',
#  'Jomo Kwame Sundaram',
#  'Lars E. O. Svensson',
#  'Jean-Claude Trichet',
#  'Antoaneta Vassileva',
#  'Phyllis Ann Wallace',
#  'Philip Green Wright',
#  'Benjamin Strong Jr.',
#  'Gershon Ben-Shakhar',
#  'Urie Bronfenbrenner',
#  'Mary Whiton Calkins',
#  'Jean-Martin Charcot',
#  'Barbara Fredrickson',
#  'Christian Gostečnik',
#  'Florence Goodenough',
#  'Jacob Robert Kantor',
#  'John Francis Leader',
#  'Jean Matter Mandler',
#  'Francis T. McAndrew',
#  'Rivka Bertisch Meir',
#  'Orval Hobart Mowrer',
#  'Eva Bendix Petersen',
#  'Ellis Paul Torrance',
#  'Robert S. Woodworth',
#  'Catharine Cox Miles',
#  'Masters and Johnson',
#  'Stephen Baskerville',
#  'Linda Royster Beito',
#  'Linda L. M. Bennett',
#  'Eileen Hunt Botting',
#  'Zbigniew Brzezinski',
#  'Walter Dean Burnham',
#  'James Smoot Coleman',
#  'Lisa García Bedolla',
#  'Christopher J. Hill',
#  'Robert C. Lieberman',
#  'Niccolò Machiavelli',
#  'J. Patrice McSherry',
#  "Guillermo O'Donnell",
#  'Gianfranco Pasquino',
#  'Sergei M. Plekhanov',
#  'Dianne Pinderhughes',
#  'Warner R. Schilling',
#  'Ekaterina Schulmann',
#  'John G. Stoessinger',
#  'Sarojini Varadappan',
#  'Elisabeth Jean Wood',
#  'John J. DiIulio Jr.',
#  'Cornelius M. Kerwin',
#  'Francesco Alberoni',
#  'Stanislav Andreski',
#  'Élisabeth Badinter',
#  'Emily Greene Balch',
#  'Krishna Bhattachan',
#  'Danielle Bleitrach',
#  'Georges Canguilhem',
#  'Maxine Leeds Craig',
#  'François de Singly',
#  'Alexander Deichsel',
#  'G. William Domhoff',
#  'Otis Dudley Duncan',
#  'Gerald L. Eberlein',
#  'Orlando Fals Borda',
#  'Heinz von Foerster',
#  'Andre Gunder Frank',
#  'Michael D. Higgins',
#  'Jacquelyne Jackson',
#  'Guy Benton Johnson',
#  'Abdelkebir Khatibi',
#  'Evelyn M. Kitagawa',
#  'Bernardo Kliksberg',
#  'Karin Knorr Cetina',
#  'Reinhart Koselleck',
#  'Siegfried Kracauer',
#  'George A. Lundberg',
#  'Stanislaw Ossowski',
#  'Moisey Ostrogorsky',
#  'Enrico Quarantelli',
#  'Gustav Ratzenhofer',
#  'Stephen Raudenbush',
#  'Renaud Sainsaulieu',
#  'Samuel A. Stouffer',
#  'Nicholas Timasheff',
#  'Jonathan H. Turner',
#  'Edvard Westermarck',
#  'Jean-Paul Willaime',
#  'Sidney M. Willhelm',
#  'John Milton Yinger',
#  'Robert Bartholomew',
#  'Ronald Stuart Burt',
#  'Willie Pearson Jr.',
#  'Jon Charles Altman',
#  'Dorothy A. Bennett',
#  'Theodore C. Bestor',
#  'Pere Bosch-Gimpera',
#  'Ernesto de Martino',
#  'John P. Harrington',
#  'Stephen C. Headley',
#  'Eva Verbitsky Hunt',
#  'C. Scott Littleton',
#  'Albert Buell Lewis',
#  'Keith F. Otterbein',
#  'Gerald F. Schroedl',
#  'William Sturtevant',
#  'Robin W. G. Horton',
#  'Benjamin Lee Whorf',
#  'Henry Carter Adams',
#  'David B. Audretsch',
#  'Leszek Balcerowicz',
#  'William A. Barnett',
#  'Peter Thomas Bauer',
#  'Matilde Bombardini',
#  'Richard A. Brealey',
#  'Frank J. Chaloupka',
#  'John Maurice Clark',
#  'David James Davies',
#  'J. Bradford DeLong',
#  'Armando Di Filippo',
#  'Kenneth G. Elzinga',
#  'Jean-Paul Fitoussi',
#  'Richard B. Freeman',
#  'James K. Galbraith',
#  'Francesco Giavazzi',
#  'Gottfried Haberler',
#  'Bohdan Hawrylyshyn',
#  'Hans-Hermann Hoppe',
#  'Thomas M. Humphrey',
#  'Matthew O. Jackson',
#  'William H. Janeway',
#  'Leonid Kantorovich',
#  'Abdul Razzaq Kemal',
#  'Nikolai Kondratiev',
#  'Lawrence B. Krause',
#  'Kevin Leyton-Brown',
#  'Lionel W. McKenzie',
#  'Bingu wa Mutharika',
#  'Arthur Melvin Okun',
#  'Arthur Cecil Pigou',
#  'Edward C. Prescott',
#  'Paul Craig Roberts',
#  'Tadeusz Rybczynski',
#  'Juan Manuel Santos',
#  'Mark Satterthwaite',
#  'L. William Seidman',
#  'Barbara J. Spencer',
#  'Richard H. Steckel',
#  'Richard Timberlake',
#  'Robert M. Townsend',
#  'Dorothy Wedderburn',
#  'Walter E. Williams',
#  'Jeffrey Wooldridge',
#  'Stephen T. Worland',
#  'Allyn Abbott Young',
#  'Richard Zeckhauser',
#  'Zeine Ould Zeidane',
#  'Fabrizio Zilibotti',
#  'Richard J. Maybury',
#  'Arturo Porzecanski',
#  'Arthur J. Bachrach',
#  ':de:Erich Benjamin',
#  'Donald T. Campbell',
#  'Hermann Ebbinghaus',
#  'Jennifer Eberhardt',
#  'Milton H. Erickson',
#  'Donata Francescato',
#  'Robert Grosseteste',
#  'Richard Herrnstein',
#  'Georg Elias Müller',
#  'Linda Papadopoulos',
#  'Ulf-Dietrich Reips',
#  'Judith Rich Harris',
#  'Susanna Rubinstein',
#  'George M. Stratton',
#  'Joan Scott Wallace',
#  'Hans-Jürgen Walter',
#  'Władysław Witwicki',
#  'Andrew N. Meltzoff',
#  'Augustus John Rush',
#  'Ibrahim Abu-Lughod',
#  'R. Michael Alvarez',
#  'Walter K. Andersen',
#  'Edward C. Banfield',
#  'James David Barber',
#  'Michael N. Barnett',
#  'Robert V. Bartlett',
#  'Thomas A. Birkland',
#  'Robert X. Browning',
#  'Elizabeth F. Cohen',
#  'Vera Micheles Dean',
#  'Keisha Lynne Ellis',
#  'Norman Finkelstein',
#  'Daniel P. Franklin',
#  'Elisabeth Gidengil',
#  'Rhiana Gunn-Wright',
#  'Donald L. Horowitz',
#  'Lawrence R. Jacobs',
#  'Stephen D. Krasner',
#  'Samuel Merrill III',
#  'Kalypso Nicolaïdis',
#  'Richard Rosecrance',
#  'Slobodan Samardžić',
#  'Yekaterina Shulman',
#  'Dennis F. Thompson',
#  'Stanley Aronowitz',
#  'Kenneth D. Bailey',
#  'Georges Balandier',
#  'E. Digby Baltzell',
#  'Margunn Bjørnholt',
#  'John David Brewer',
#  'Walter F. Buckley',
#  'Michel de Certeau',
#  'Stefan Czarnowski',
#  'Mustafa Emirbayer',
#  'Hugo O. Engelmann',
#  'Georges Friedmann',
#  'Ludwig Gumplowicz',
#  'Jeffrey K. Hadden',
#  'Maurice Halbwachs',
#  'Wilhelm Heitmeyer',
#  'Miriam M. Johnson',
#  'Boris Kagarlitsky',
#  'Baruch Kimmerling',
#  'Maksim Kovalevsky',
#  'Lucien Lévy-Bruhl',
#  'Gilles Lipovetsky',
#  'Harriet Martineau',
#  'Humberto Maturana',
#  'J. Clyde Mitchell',
#  'Franz Oppenheimer',
#  'Orlando Patterson',
#  'Friedrich Pollock',
#  'Samuel H. Preston',
#  'Bindeshwar Pathak',
#  'James Mahmud Rice',
#  'Robert J. Sampson',
#  'Emanuel Schegloff',
#  'William H. Sewell',
#  'Jeremy J. Shapiro',
#  'Tamotsu Shibutani',
#  'Alexander Tarasov',
#  'Ferdinand Tönnies',
#  'Lester Frank Ward',
#  'Leopold von Wiese',
#  'Benjamin Zablocki',
#  'Eviatar Zerubavel',
#  'Florian Znaniecki',
#  'Harriet Zuckerman',
#  'Theodor W. Adorno',
#  'Claude S. Fischer',
#  'Joseph Schumpeter',
#  'Dmitri Bondarenko',
#  'Philippe Bourgois',
#  'Julio Caro Baroja',
#  'Harold C. Conklin',
#  'Ella Cara Deloria',
#  'Abdellah Hammoudi',
#  'K. David Harrison',
#  'Alfred E. Johnson',
#  'Harold E. Lambert',
#  'Jonathan M. Marks',
#  'Harald E.L. Prins',
#  'Tobias Schneebaum',
#  'Christen A. Smith',
#  'Jacques Soustelle',
#  'Marilyn Strathern',
#  'Isobel Mary White',
#  'E. Adamson Hoebel',
#  'Charles H. McNutt',
#  'Orley Ashenfelter',
#  'Marianne Bertrand',
#  'William Beveridge',
#  'Olivier Blanchard',
#  'Avishay Braverman',
#  'John Francis Bray',
#  'James M. Buchanan',
#  'Richard Cantillon',
#  'Richard N. Cooper',
#  'Russell W. Cooper',
#  'Christopher Coyne',
#  'Stephen J. Dubner',
#  'Martin Eichenbaum',
#  'Barry Eichengreen',
#  'Vanessa Erogbogbo',
#  'Nikolay Fedorenko',
#  'Price V. Fishback',
#  'William Fleetwood',
#  'David D. Friedman',
#  'Connel Fullenkamp',
#  'A. Ronald Gallant',
#  'Dominique Guellec',
#  'James D. Hamilton',
#  'Lars Peter Hansen',
#  'Robert Heilbroner',
#  'Christian Hellwig',
#  'Michael C. Jensen',
#  'Dale W. Jorgenson',
#  'Nobuhiro Kiyotaki',
#  'Tjalling Koopmans',
#  'Roger C. Kormendi',
#  'Stanley Lebergott',
#  'Axel Leijonhufvud',
#  'Leonardus Lessius',
#  'Donald MacDougall',
#  'Gerard de Malynes',
#  'Deirdre McCloskey',
#  'Franco Modigliani',
#  'Richard R. Nelson',
#  "Sharyn O'Halloran",
#  'V. R. Panchamukhi',
#  'Maffeo Pantaleoni',
#  'M. Hashem Pesaran',
#  'Bernard van Praag',
#  'Raymond de Roover',
#  'Gilles Saint-Paul',
#  'Thomas J. Sargent',
#  'Jean-Baptiste Say',
#  'Louis Auguste Say',
#  'William F. Sharpe',
#  'Masaaki Shirakawa',
#  'Andrzej Sławiński',
#  'Willem Somermeyer',
#  'Arun Sundararajan',
#  'Subramanian Swamy',
#  'Edward Szczepanik',
#  'Rodrigue Tremblay',
#  'Fernando Vianello',
#  'John Glen Wardrop',
#  'Edward Chamberlin',
#  'Sebastián Edwards',
#  'Robert J. Shiller',
#  'Roberto Assagioli',
#  'Simon Baron-Cohen',
#  'Frederic Bartlett',
#  'Nathaniel Branden',
#  'Brian Butterworth',
#  'Virgilio Enriquez',
#  'Bertram Gawronski',
#  'Edwin Ray Guthrie',
#  'Nicholas Humphrey',
#  'Marcia K. Johnson',
#  'Nadeen L. Kaufman',
#  'Lawrence Kohlberg',
#  'Arthur Kornhauser',
#  'Marsha M. Linehan',
#  'William McDougall',
#  'Albert Nalchajyan',
#  'Charles E. Osgood',
#  'James W. Prescott',
#  'Cecil R. Reynolds',
#  'Shlomo Sawilowsky',
#  'Stanley Schachter',
#  'Walter Dill Scott',
#  'Sara Shettleworth',
#  'Hunter B. Shirley',
#  'Jeffrey S. Tanaka',
#  'Philip E. Tetlock',
#  'Adelbert Ames Jr.',
#  'Renée Baillargeon',
#  'Kelly D. Brownell',
#  'Kenneth J. Gergen',
#  'Kirk J. Schneider',
#  'Martha Ackelsberg',
#  'Charles R. Adrian',
#  'Bethany Albertson',
#  'Daniel P. Aldrich',
#  'Benedict Anderson',
#  'Richard K. Ashley',
#  'Frank Baumgartner',
#  'Phineas Baxandall',
#  'Arthur F. Bentley',
#  'B. Anthony Bogues',
#  'Partha Chatterjee',
#  'Morgan Lyon Cotti',
#  'Jadwiga Emilewicz',
#  'C. Christine Fair',
#  'Annette Baker Fox',
#  'William T. R. Fox',
#  'Michael Gallagher',
#  'Benjamin Ginsberg',
#  'Marc Hetherington',
#  'Ashley E. Jardina',
#  'Willmoore Kendall',
#  'Herbert Kitschelt',
#  'Richard Ned Lebow',
#  'Mohammed Barkindo',
#  'Brigitte L. Nacos',
#  "Cornelius O'Leary",
#  'Mahesh Rangarajan',
#  'Pearl T. Robinson',
#  'Vivien A. Schmidt',
#  'Hossein Seifzadeh',
#  'Stephen Skowronek',
#  'Jean Edward Smith',
#  'Marianne Thyrring',
#  'Stephen Van Evera',
#  'Bruce A. Williams',
#  'William Wohlforth',
#  'Susan L. Woodward',
#  'M. Crawford Young',
#  'Edvin Kanka Ćudić',
#  'Daniel W. Drezner',
#  'A. F. K. Organski',
#  'Janet Abu-Lughod',
#  'Aaron Antonovsky',
#  'Giovanni Arrighi',
#  'Jean Baudrillard',
#  'Howard P. Becker',
#  'Howard S. Becker',
#  'Robert N. Bellah',
#  'Eduard Bernstein',
#  'Robert Bierstedt',
#  'Kathleen M. Blee',
#  'Olivier Bobineau',
#  'Thomas Bottomore',
#  'David G. Bromley',
#  'Hauke Brunkhorst',
#  'Dieter Claessens',
#  'Douglas E. Cowan',
#  'Leonore Davidoff',
#  'Christine Delphy',
#  'W. E. B. Du Bois',
#  'Mitchell Duneier',
#  'Maurice Duverger',
#  'Friedrich Engels',
#  'Myra Marx Ferree',
#  'Harold Garfinkel',
#  'Yasunosuke Gonda',
#  'Mark Granovetter',
#  'Richard Grathoff',
#  'Georges Gurvitch',
#  'Eszter Hargittai',
#  'Robert J. Holton',
#  'George C. Homans',
#  'Philip N. Howard',
#  'John Keith Irwin',
#  'Lewis Wade Jones',
#  'Vytautas Kavolis',
#  'Julieta Kirkwood',
#  'Mirra Komarovsky',
#  'Andrey Korotayev',
#  'Richard Lachmann',
#  'John Levi Martin',
#  'Loet Leydesdorff',
#  'Anthony Ludovici',
#  'Richard Machalek',
#  'Michel Maffesoli',
#  'Sinisa Malesevic',
#  'Peter K. Manning',
#  'Marshall McLuhan',
#  'Robert K. Merton',
#  'Andrew Pickering',
#  'Helmuth Plessner',
#  'Alejandro Portes',
#  'Nicos Poulantzas',
#  'Walter W. Powell',
#  'Adolphe Quetelet',
#  'Charles C. Ragin',
#  'Roland Robertson',
#  'Terje Rød-Larsen',
#  'Rubén G. Rumbaut',
#  'Giovanni Sartori',
#  'Thomas J. Scheff',
#  'Herbert Schiller',
#  'Allan Schnaiberg',
#  'Michael Schwartz',
#  'François Simiand',
#  'Herbert A. Simon',
#  'Dorothy E. Smith',
#  'Stephen C. Smith',
#  'Lynette Spillman',
#  'George Steinmetz',
#  'Edwin Sutherland',
#  'Richard Swedberg',
#  'Mariana Valverde',
#  'Francisco Varela',
#  'Aninhalli Vasavi',
#  'Thorstein Veblen',
#  'Alfred Vierkandt',
#  'Shiv Visvanathan',
#  'John Westergaard',
#  'Douglas R. White',
#  'William H. Whyte',
#  'Michel Wieviorka',
#  'Raymond Williams',
#  'Erik Olin Wright',
#  'F. Stuart Chapin',
#  'David W. Garland',
#  'Leonard Hobhouse',
#  'Robert D. Putnam',
#  'Sudhir Venkatesh',
#  'Evelyn Blackwood',
#  'Kari Bruwelheide',
#  'Napoleon Chagnon',
#  'Carleton S. Coon',
#  'Philippe Descola',
#  'Katherine Dunham',
#  'Maurice Godelier',
#  'Jacquetta Hawkes',
#  'Jeffrey S. Juris',
#  'Alice Beck Kehoe',
#  'Anatoly Khazanov',
#  'Dorinne K. Kondo',
#  'Charles H. Kraft',
#  'Theodora Kroeber',
#  'George E. Marcus',
#  'John Alden Mason',
#  'Phillip McArthur',
#  'Marshall Sahlins',
#  'Afanasy Shchapov',
#  'Camilla Wedgwood',
#  'Catherine Berndt',
#  'Fernando Alvarez',
#  'Enrique R. Arzac',
#  'Orazio Attanasio',
#  'Nikolai Baibakov',
#  'Ludwig Bamberger',
#  'Abhijit Banerjee',
#  'Frédéric Bastiat',
#  'Mahamudu Bawumia',
#  'Barbara Bergmann',
#  'C. Fred Bergsten',
#  'Jagdish Bhagwati',
#  'William K. Black',
#  'Francine D. Blau',
#  'Richard Blundell',
#  'William Brainard',
#  'Phillip D. Cagan',
#  'John Y. Campbell',
#  'Agustín Carstens',
#  'Seweryn Chajtman',
#  'John Bates Clark',
#  'William D. Clark',
#  'John H. Cochrane',
#  'Vincent Crawford',
#  'Charles Davenant',
#  'Stanley Engerman',
#  'José Luis Espert',
#  'Martin Feldstein',
#  'Randall K. Filer',
#  'Norton Garfinkle',
#  'John Geanakoplos',
#  'Jacques Généreux',
#  'Victor Ginsburgh',
#  'Charles Goodhart',
#  'Robert J. Gordon',
#  'Elgin Groseclose',
#  'John Haltiwanger',
#  'Arnold Harberger',
#  'Jerry A. Hausman',
#  'Carolyn Heinrich',
#  'Michael J. Hicks',
#  'Jack Hirshleifer',
#  'Samuel Hollander',
#  'Harold Hotelling',
#  'Ravi Jagannathan',
#  'Robert A. Jarrow',
#  'Lawrence F. Katz',
#  'Stephanie Kelton',
#  'Steven Landsburg',
#  'Edward E. Leamer',
#  'Wassily Leontief',
#  'Bernard Lonergan',
#  'Stephen J. Luczo',
#  'Adil Abdul-Mahdi',
#  'Edmond Malinvaud',
#  'Bennett McCallum',
#  'Richard McKelvey',
#  'Warwick McKibbin',
#  'Robert C. Merton',
#  'John Stuart Mill',
#  'Ludwig von Mises',
#  'Frederic Mishkin',
#  'Baidyanath Misra',
#  'Jonathan Morduch',
#  'Michio Morishima',
#  'Mohan Munasinghe',
#  'Robert P. Murphy',
#  'Richard Musgrave',
#  'Nikolay Nenovsky',
#  'John von Neumann',
#  'William Nordhaus',
#  'Maurice Obstfeld',
#  'Jacques Parizeau',
#  'William Paterson',
#  'Christina Paxson',
#  'Thomas Philippon',
#  'William Phillips',
#  'James M. Poterba',
#  'François Quesnay',
#  'Martin Ravallion',
#  'Dennis Robertson',
#  'Abraham Robinson',
#  'Nathan Rosenberg',
#  'Ariel Rubinstein',
#  'Anthony Saunders',
#  'Thomas Schelling',
#  'Theodore Schultz',
#  'E. F. Schumacher',
#  'Molly Scott Cato',
#  'G. L. S. Shackle',
#  'Artyom Shneyerov',
#  'Miguel Sidrauski',
#  'Hans-Werner Sinn',
#  'T. N. Srinivasan',
#  'Lawrence Summers',
#  'Lester G. Telser',
#  'William Thompson',
#  'Alejandro Toledo',
#  'Kenneth E. Train',
#  'Sho-Chieh Tsiang',
#  'Catherine Tucker',
#  'Yanis Varoufakis',
#  'Anthony Venables',
#  'Thomas Vietorisz',
#  'Robert W. Vishny',
#  'Richard D. Wolff',
#  'Holbrook Working',
#  'Simon Wren-Lewis',
#  'Xenophon Zolotas',
#  'Albert Bergstrom',
#  'George J. Borjas',
#  'William L. Breit',
#  'Alfred H. Conrad',
#  'Hernando de Soto',
#  'Target page name',
#  'Robert Lucas Jr.',
#  'David McWilliams',
#  'Pereire brothers',
#  'Philip Wicksteed',
#  'Charles Wolf Jr.',
#  'Harlene Anderson',
#  'Jerome H. Barkow',
#  'Geoffrey Beattie',
#  'Larry E. Beutler',
#  'Theodore H. Blau',
#  'Donald Broadbent',
#  'Ruth M. J. Byrne',
#  'Kenneth B. Clark',
#  'Martin Dannecker',
#  'Gordon G. Gallup',
#  'Susan Gathercole',
#  'Mary Cover Jones',
#  'Otto F. Kernberg',
#  'Akiyoshi Kitaoka',
#  'Jan van der Lans',
#  'Elizabeth Loftus',
#  'David McClelland',
#  'James McClelland',
#  'Wolfgang Metzger',
#  'Hugo Münsterberg',
#  'LeShawndra Price',
#  'Robert Rosenthal',
#  'Barbara Rothbaum',
#  ...]

# %%
s_ = '(?: )?'.join(sorted(all_names, key = len, reverse = True)) +
# Out:
# ['Peter Abell',
#  'Mark Abrams',
#  'Janet Abu-Lughod',
#  'Jane Addams',
#  'Richard Alba',
#  'Francesco Alberoni',
#  'Martin Albrow',
#  'Jeffrey C. Alexander',
#  'Edwin Amenta',
#  'Nancy Ammerman',
#  'Eric Anderson ',
#  'Elijah Anderson',
#  'Stanislav Andreski',
#  'Aaron Antonovsky',
#  'Arjun Appadurai',
#  'Andrew Arato',
#  'Margaret Archer',
#  'Hannah Arendt',
#  'Alcira Argumedo',
#  'Raymond Aron',
#  'Stanley Aronowitz',
#  'Giovanni Arrighi',
#  'Johan Asplund',
#  'Vilhelm Aubert',
#  'Francisco Ayala ',
#  'Élisabeth Badinter',
#  'Patrick Baert',
#  'Sergio Bagú',
#  'Kenneth D. Bailey ',
#  'Georges Balandier',
#  'Emily Greene Balch',
#  'Robert Balch',
#  'E. Digby Baltzell',
#  'Eileen Barker',
#  'S. Barry Barnes',
#  'Liberty Barnes',
#  'Roland Barthes',
#  'Roger Bastide',
#  'Gregory Bateson',
#  'Jean Baubérot',
#  'Jean Baudrillard',
#  'Zygmunt Bauman',
#  'Peter Bearman',
#  'Ulrich Beck',
#  'Gary Becker',
#  'Howard P. Becker',
#  'Howard S. Becker',
#  'Jens Beckert',
#  'Richard Fritz Behrendt',
#  'Daniel Bell',
#  'Robert N. Bellah',
#  'Walden Bello',
#  'Reinhard Bendix',
#  'Walter Benjamin',
#  'Albert Benschop',
#  'Joseph Berger ',
#  'Peter L. Berger',
#  'Pierre L. van den Berghe',
#  'Henri Bergson',
#  'Jessie Bernard',
#  'Eduard Bernstein',
#  'Jean-Michel Berthelot',
#  'Andre Beteille',
#  'Krishna Bhattachan',
#  'Robert Bierstedt',
#  'Norman Birnbaum',
#  'Margunn Bjørnholt',
#  'Donald Black ',
#  'Peter Blau',
#  'Kathleen M. Blee',
#  'Gisela Bleibtreu-Ehrenberg',
#  'Danielle Bleitrach',
#  'David Bloor',
#  'Herbert Blumer',
#  'Olivier Bobineau',
#  'Luc Boltanski',
#  'Scott Boorman',
#  'Ernst Borinski',
#  'Thomas Bottomore',
#  'Raymond Boudon',
#  'Pierre Bourdieu',
#  'Victor Branford',
#  'Ronald Breiger',
#  'John David Brewer',
#  'Carl Brinkmann',
#  'David G. Bromley',
#  'Rogers Brubaker',
#  'Hauke Brunkhorst',
#  'Walter F. Buckley',
#  'Michael Burawoy',
#  'Ernest Burgess',
#  'Tom R. Burns',
#  'Judith Butler',
#  'Roger Caillois',
#  'Craig Calhoun',
#  'Michel Callon',
#  'Elias Canetti',
#  'Georges Canguilhem',
#  'Fernando Henrique Cardoso',
#  'Kathleen Carley',
#  'Robert Castel',
#  'Julieta Castellanos',
#  'Manuel Castells',
#  'Cornelius Castoriadis',
#  'Michel de Certeau',
#  'Christopher Chase-Dunn',
#  'Louis Chauvel',
#  'Nancy Chodorow',
#  'Chua Beng Huat',
#  'Aaron Cicourel',
#  'Dieter Claessens',
#  'Lars Clausen',
#  'Marshall B. Clinard',
#  'Clifford Clogg',
#  'Richard Cloward',
#  'Philip N. Cohen',
#  'Ronald L. Cohen',
#  'Stanley Cohen ',
#  'James Samuel Coleman',
#  'Harry Collins',
#  'Patricia Hill Collins',
#  'Randall Collins',
#  'Auguste Comte',
#  'Dalton Conley',
#  'Paul Connerton',
#  'Charles Cooley',
#  'Lewis A. Coser',
#  'Carl J. Couch',
#  'Douglas E. Cowan',
#  'Maxine Leeds Craig',
#  'Colin Crouch',
#  'Michel Crozier',
#  'Agustin Cueva',
#  'Stefan Czarnowski',
#  'Robert Dahl',
#  'Ralf Dahrendorf',
#  'Dankwart Danckwerts',
#  'Randy David',
#  'Leonore Davidoff',
#  'Kingsley Davis',
#  'Georges Davy',
#  'François de Singly',
#  'Régis Debray',
#  'Alexander Deichsel',
#  'Christine Delphy',
#  'Gilles Deleuze',
#  'Donatella della Porta',
#  'Bogdan Denitch',
#  'Régis Dericquebourg',
#  'Jacques Derrida',
#  'Heinz Dieterich',
#  'Wilhelm Dilthey',
#  'Helen Dinerman',
#  'Paul DiMaggio',
#  'Georgi Dimitrov Dimitrov',
#  'Stuart C. Dodd',
#  'G. William Domhoff',
#  'Mary Douglas',
#  'Tommy Douglas',
#  'W. E. B. Du Bois',
#  'Denis Duclos',
#  'Otis Dudley Duncan',
#  'Mitchell Duneier',
#  'Eric Dunning',
#  'Émile Durkheim',
#  'Troy Duster',
#  'Maurice Duverger',
#  'Jean Duvignaud',
#  'Gerald L. Eberlein',
#  'Alain Ehrenberg',
#  'Eugen Ehrlich',
#  'Shmuel Noah Eisenstadt',
#  'Riane Eisler',
#  'Norbert Elias',
#  'Jon Elster',
#  'Mustafa Emirbayer',
#  'Hugo O. Engelmann',
#  'Friedrich Engels',
#  'Paula England',
#  'Ronald Enroth',
#  'Kai T. Erikson',
#  'Fernando Escalante Gonzalbo',
#  'Amitai Etzioni',
#  'Peter B. Evans',
#  'Orlando Fals Borda',
#  'Frantz Fanon',
#  'Rick Fantasia',
#  'Thomas Fararo',
#  'Paul Fauconnet',
#  'Joe Feagin',
#  'Fei Xiaotong',
#  'Anuška Ferligoj',
#  'Florestan Fernandes',
#  'Myra Marx Ferree',
#  'Enrico Ferri ',
#  'Gary Alan Fine',
#  'George Fitzhugh',
#  'Crystal Marie Fleming',
#  'Peter Flora',
#  'Heinz von Foerster',
#  'Pim Fortuyn',
#  'Daniel Foss',
#  'John Bellamy Foster',
#  'Michel Foucault',
#  'Alfred Jules Émile Fouillée',
#  'Charles Fourier',
#  'Renée Fox',
#  'Andre Gunder Frank',
#  'Nancy Fraser',
#  'Hans Freyer',
#  'Gilberto Freyre',
#  'Georges Friedmann',
#  'Steve Fuller ',
#  'Celso Furtado',
#  'Luciano Gallino',
#  'Francis Galton',
#  'Johan Galtung',
#  'Diego Gambetta',
#  'Harold Garfinkel',
#  'Marcel Gauchet',
#  'John Gaventa',
#  'Patrick Geddes',
#  'Clifford Geertz',
#  'Arnold Gehlen',
#  'Theodor Geiger',
#  'Ernest Gellner',
#  'G. S. Ghurye',
#  'Anthony Giddens',
#  'Franklin Henry Giddings',
#  'Nigel Gilbert',
#  'Charlotte Perkins Gilman',
#  'Paul Gilroy',
#  'Salvador Giner',
#  'Corrado Gini',
#  'Morris Ginsberg',
#  'Herbert Gintis',
#  'Henry Giroux',
#  'Todd Gitlin',
#  'Barney Glaser',
#  'David Glass ',
#  'Barry Glassner',
#  'Nathan Glazer',
#  'Max Gluckman',
#  'Erving Goffman',
#  'Steven J. Gold',
#  'Lucien Goldmann',
#  'Jack Goldstone',
#  'Yasunosuke Gonda',
#  'Jeff Goodwin',
#  'Alvin Gouldner',
#  'Ziya Gökalp',
#  'Isacque Graeber',
#  'Antonio Gramsci',
#  'Mark Granovetter',
#  'Richard Grathoff',
#  'Liah Greenfeld',
#  'Leonid Grinin',
#  'Ludwig Gumplowicz',
#  'Dipankar Gupta',
#  'Georges Gurvitch',
#  'Dimitrie Gusti',
#  'Jürgen Habermas',
#  'Jeffrey K. Hadden',
#  'Maurice Halbwachs',
#  'Drew Halfmann',
#  'John A. Hall',
#  'Stuart Hall ',
#  'Donna Haraway',
#  'Eszter Hargittai',
#  'Marta Harnecker',
#  'Chandrakala A. Hate',
#  'Darnell Hawkins',
#  'Peter Hedström',
#  'Samuel Heilman',
#  'Wilhelm Heitmeyer',
#  'Dirk Helbing',
#  'Horst Helle',
#  'Ágnes Heller',
#  'Celia Stopnicka Heller',
#  'Will Herberg',
#  'John Heritage',
#  'Robert Hertz',
#  'Danièle Hervieu-Léger',
#  'Michael D. Higgins',
#  'Paul Hirst',
#  'Thomas Hobbes',
#  'Arlie Russell Hochschild',
#  'Richard Hoggart',
#  'John Holloway ',
#  'Robert J. Holton',
#  'George C. Homans',
#  'Axel Honneth',
#  'Ida R. Hoos',
#  'Max Horkheimer',
#  'Irving Louis Horowitz',
#  'Eugenio María de Hostos',
#  'Philip N. Howard',
#  'Spomenka Hribar',
#  'Everett Hughes ',
#  'Stephen J. Hunt',
#  'Octavio Ianni',
#  'Ibn Khaldun',
#  'Kancha Ilaiah',
#  'Eva Illouz',
#  'Harold Innis',
#  'John Keith Irwin',
#  'Eliezer Jaffe',
#  'Jacquelyne Jackson',
#  'Stevi Jackson',
#  'Janet L. Jacobs',
#  'Marie Jahoda',
#  'Marie Jaisson',
#  'Ayesha Jalal',
#  'Fredric Jameson',
#  'Morris Janowitz',
#  'James M. Jasper',
#  'Gail Jefferson',
#  'Yasmin Jiwani',
#  'Hans Joas',
#  'Carole Joffe',
#  'Benton Johnson',
#  'Guy Benton Johnson',
#  'Miriam M. Johnson',
#  'Rodrigo Jokisch',
#  'Frank Lancaster Jones',
#  'Lewis Wade Jones',
#  'Danny Jorgensen',
#  'Paul Jorion',
#  'Dirk Kaesler',
#  'Boris Kagarlitsky',
#  'Irawati Karve',
#  'Elihu Katz',
#  'Nitasha Kaul',
#  'Karl Kautsky',
#  'Vytautas Kavolis',
#  'Frances Kellor',
#  'Stephen A. Kent',
#  'Lane Kenworthy',
#  'Abdelkebir Khatibi',
#  'Aquila Berlas Kiani',
#  'Baruch Kimmerling',
#  'Susan Myra Kingsbury',
#  'Julieta Kirkwood',
#  'Evelyn M. Kitagawa',
#  'John Kitsuse',
#  'Gabriele Klein',
#  'Bernardo Kliksberg',
#  'Eric Klinenberg',
#  'Karin Knorr Cetina',
#  'Antonina Kłoskowska',
#  'Katsuya Kodama',
#  'Mirra Komarovsky',
#  'René König',
#  'Andrey Korotayev',
#  'Reinhart Koselleck',
#  'Maksim Kovalevsky',
#  'Siegfried Kracauer',
#  'Julia Kristeva',
#  'Peter Kropotkin',
#  'Eugene M. Kulischer',
#  'Charles Kurzman',
#  'Martin Kusch',
#  'William Labov',
#  'Jacques Lacan',
#  'Richard Lachmann',
#  'Ernesto Laclau',
#  'Joyce Ladner',
#  'Imre Lakatos',
#  'Janja Lalich',
#  'Diane Lamoureux',
#  'David C. Lane',
#  'Ralph Larkin',
#  'Scott Lash',
#  'Harold Lasswell',
#  'Bruno Latour',
#  'John Law ',
#  'Gustave Le Bon',
#  'Emil Lederer',
#  'Henri Lefebvre',
#  'Charles Lemert',
#  'Vladimir Lenin',
#  'Gerhard Lenski',
#  'Yuri Levada',
#  'John Levi Martin',
#  'Claude Lévi-Strauss',
#  'Jack Levin',
#  'Barry B. Levine',
#  'Ruth Levitas',
#  'Daniel Levy ',
#  'Lucien Lévy-Bruhl',
#  'Kurt Lewin',
#  'Loet Leydesdorff',
#  'Li Yinhe',
#  'Nan Lin',
#  'Alfred R. Lindesmith',
#  'Frederick B. Lindstrom',
#  'Gilles Lipovetsky',
#  'Seymour Martin Lipset',
#  'Émile Littré',
#  'Omar Lizardo',
#  'John Locke',
#  'David Lockwood ',
#  'Joseph Lopreato',
#  'Leo Löwenthal',
#  'Michael Löwy',
#  'Nathalie Luca',
#  'Thomas Luckmann',
#  'Anthony Ludovici',
#  'Niklas Luhmann',
#  'György Lukács',
#  'Steven Lukes',
#  'George A. Lundberg',
#  'Rosa Luxemburg',
#  'Robert Staughton Lynd',
#  'Jean-François Lyotard',
#  'Amin Maalouf',
#  'Richard Machalek',
#  'Robert Morrison MacIver',
#  'Donald Angus MacKenzie',
#  'Annie Marion MacLean',
#  'Michel Maffesoli',
#  'Sinisa Malesevic',
#  'Bronisław Malinowski',
#  'Roberto Mangabeira Unger',
#  'Michael Mann ',
#  'Karl Mannheim',
#  'Peter K. Manning',
#  'José María Maravall',
#  'Herbert Marcuse',
#  'Władysław Markiewicz',
#  'Dennis Marsden',
#  'Alfred Marshall',
#  'Everett Dean Martin',
#  'Jean Martin ',
#  'Harriet Martineau',
#  'Vladimir Martynenko',
#  'Gary T. Marx',
#  'Karl Marx',
#  'Douglas Massey',
#  'Brian Massumi',
#  'Humberto Maturana',
#  'Marcel Mauss',
#  'Doug McAdam',
#  'Robert McKenzie ',
#  'Marshall McLuhan',
#  'George Herbert Mead',
#  'Margaret Mead',
#  'Stephen Mennell',
#  'Fatema Mernissi',
#  'Robert K. Merton',
#  'Michael Messner',
#  'John W. Meyer',
#  'Robert Michels',
#  'Ralph Miliband',
#  'C. Wright Mills',
#  'Andrew Milner',
#  'Ann Mische',
#  'Munesuke Mita',
#  'J. Clyde Mitchell',
#  'Shinji Miyadai',
#  'Tariq Modood',
#  'Abraham Moles',
#  'Montesquieu',
#  'James D. Montgomery ',
#  'Edgar Morin',
#  'Gaetano Mosca',
#  'Serge Moscovici',
#  'Chantal Mouffe',
#  'Daniel Patrick Moynihan',
#  'Radhakamal Mukerjee',
#  'Peter A. Munch',
#  'Charles Murray ',
#  'Gunnar Myrdal',
#  'Ashis Nandy',
#  'Vicenç Navarro',
#  'Antonio Negri',
#  'Oswald von Nell-Breuning',
#  'Otto Neurath',
#  'Otto Newman',
#  'Norman H. Nie',
#  'Robert Nisbet',
#  'Helga Nowotny',
#  'Claus Offe',
#  'Lloyd Ohlin',
#  'Michael Omi',
#  'Gail Omvedt',
#  'T. K. Oommen',
#  'Franz Oppenheimer',
#  'Hossein Oreizi',
#  'José Ortega y Gasset',
#  'Stanislaw Ossowski',
#  'Moisey Ostrogorsky',
#  'Vilfredo Pareto',
#  'Robert E. Park',
#  'Talcott Parsons',
#  'Jean-Claude Passeron',
#  'Orlando Patterson',
#  'Karl Pearson',
#  'Jacqueline Peschard',
#  'James Petras',
#  'Jean Piaget',
#  'Andrew Pickering',
#  'Trevor Pinch',
#  'Michael Plekon',
#  'Helmuth Plessner',
#  'Joel M. Podolny',
#  'Karl Polanyi',
#  'Friedrich Pollock',
#  'Karl Popper',
#  'John Porter ',
#  'Alejandro Portes',
#  'Adam Possamai',
#  'Nicos Poulantzas',
#  'Émile Poulat',
#  'Walter W. Powell',
#  'Ricardo Pozas Arciniega',
#  'Samuel H. Preston',
#  'Ilya Prigogine',
#  'Pierre-Joseph Proudhon',
#  'Adam Przeworski',
#  'Jade Puget',
#  'Bindeshwar Pathak',
#  'Ankur Pare',
#  'Sigrid Quack',
#  'Enrico Quarantelli',
#  'Adolphe Quetelet',
#  'Richard Quinney',
#  'Charles C. Ragin',
#  'Gustav Ratzenhofer',
#  'Stephen Raudenbush',
#  'Aviad Raz',
#  'Sal Restivo',
#  'John Rex',
#  'James Mahmud Rice',
#  'Sam Richards ',
#  'David Riesman',
#  'George Ritzer',
#  'Roland Robertson',
#  'William I. Robinson',
#  'Terje Rød-Larsen',
#  'Jesús M. de Miguel Rodríguez',
#  'Arnold Marshall Rose',
#  'Gillian Rose',
#  'Nikolas Rose',
#  'Paul Rosenfels',
#  'Eugen Rosenstock-Huessy',
#  'Jean-Jacques Rousseau',
#  'Rubén G. Rumbaut',
#  'Arne Runeberg',
#  'Harvey Sacks',
#  'Renaud Sainsaulieu',
#  'Robert J. Sampson',
#  'Pierre Sansot',
#  'Boaventura de Sousa Santos',
#  'Giovanni Sartori',
#  'Saskia Sassen',
#  'Peter Robert Saunders',
#  'Ferdinand de Saussure',
#  'Albert Schäffle',
#  'Thomas J. Scheff',
#  'Emanuel Schegloff',
#  'Max Scheler',
#  'Helmut Schelsky',
#  'Juraj Schenk',
#  'Herbert Schiller',
#  'Kurt C. Schlichting',
#  'Wolfgang Schluchter',
#  'Paul Schnabel',
#  'Allan Schnaiberg',
#  'Juliet Schor',
#  'Alfred Schütz',
#  'Michael Schwartz ',
#  'John Scott ',
#  'Jean Séguy',
#  'Steven Seidman',
#  'Pınar Selek',
#  'Philip Selznick',
#  'Amartya Sen',
#  'Richard Sennett',
#  'William H. Sewell',
#  'Steven Shapin',
#  'Jeremy J. Shapiro',
#  'Ali Shariati',
#  'Tamotsu Shibutani',
#  'Edward Shils',
#  'Volkmar Sigusch',
#  'Charles E. Silberman',
#  'François Simiand',
#  'Georg Simmel',
#  'Herbert A. Simon',
#  'Theda Skocpol',
#  'Albion Woodbury Small',
#  'Neil Smelser',
#  'Adam Smith',
#  'Christian Smith ',
#  'Dorothy E. Smith',
#  'Stephen C. Smith ',
#  'Tom Snijders',
#  'David A. Snow',
#  'Werner Sombart',
#  'Georges Sorel',
#  'Bernardo Sorj',
#  'Pitirim Sorokin',
#  'Herbert Spencer',
#  'Oswald Spengler',
#  'Lynette Spillman',
#  'Hasso Spode',
#  'Susan Star',
#  'David C. Stark',
#  'Paul Starr',
#  'Rodolfo Stavenhagen',
#  'George Steinmetz ',
#  'Samuel A. Stouffer',
#  'Lucy Suchman',
#  'Thomas Sugrue',
#  'William Graham Sumner',
#  'Eilert Sundt',
#  'Edwin Sutherland',
#  'Ian Svenonius',
#  'Richard Swedberg',
#  'Ann Swidler',
#  'Iván Szelényi',
#  'Piotr Sztompka',
#  'Hippolyte Taine',
#  'Yasuma Takada',
#  'Salim Tamari',
#  'Lisa Taraki',
#  'Alexander Tarasov',
#  'Gabriel Tarde',
#  'Sidney Tarrow',
#  'R. H. Tawney',
#  'Dorceta Taylor',
#  'Laurie Taylor ',
#  'Göran Therborn',
#  'W. I. Thomas',
#  'E. P. Thompson',
#  'Thomas Patrick Thompson',
#  'John Thompson ',
#  'Sarah Thornton',
#  'Charles Tilly',
#  'Nicholas Timasheff',
#  'Valery Tishkov',
#  'Alexis de Tocqueville',
#  'Ferdinand Tönnies',
#  'Alain Touraine',
#  'Peter Townsend ',
#  'Judith Treas',
#  'Renato Treves',
#  'Ernst Troeltsch',
#  'Raimo Tuomela',
#  'Sherry Turkle',
#  'Jonathan H. Turner',
#  'Victor Turner',
#  'France Winddance Twine',
#  'Edward Burnett Tylor',
#  'John Urry ',
#  'Mariana Valverde',
#  'Francisco Varela',
#  'Aninhalli Vasavi',
#  'Thorstein Veblen',
#  'Ruut Veenhoven',
#  'Calvin Veltman',
#  'Alfred Vierkandt',
#  'George Edgar Vincent',
#  'Paul Virilio',
#  'Shiv Visvanathan',
#  'Loïc Wacquant',
#  'Peter Wagner ',
#  'Sylvia Walby',
#  'Immanuel Wallerstein',
#  'Lester Frank Ward',
#  'Vron Ware',
#  'Emile Waxweiler',
#  'Beatrice Webb',
#  'Alfred Weber',
#  'Marianne Weber',
#  'Max Weber',
#  'Frank Webster ',
#  'Margaret Weir',
#  'Barry Wellman',
#  'John Westergaard',
#  'Edvard Westermarck',
#  'Nathan Whetten',
#  'Douglas R. White',
#  'Harrison White',
#  'William Foote Whyte',
#  'William H. Whyte',
#  'Saskia Wieringa',
#  'Leopold von Wiese',
#  'Michel Wieviorka',
#  'Jean-Paul Willaime',
#  'Sidney M. Willhelm',
#  'Raymond Williams',
#  'Paul Willis',
#  'Helmut Willke',
#  'William Julius Wilson',
#  'Howard Winant',
#  'Christopher Winship',
#  'Louis Wirth',
#  'Edmund Wnuk-Lipinski',
#  'Mary Wollstonecraft',
#  'Steve Woolgar',
#  'Monroe Work',
#  'Erik Olin Wright',
#  'Robert Wuthnow',
#  'Kazuo Yamaguchi',
#  'Masahiro Yamada ',
#  'John Milton Yinger',
#  'Michael Young, Baron Young of Dartington',
#  'Benjamin Zablocki',
#  'Mayer Zald',
#  'Tatyana Zaslavskaya',
#  'René Zavaleta Mercado',
#  'Viviana Zelizer',
#  'Eviatar Zerubavel',
#  'Jean Ziegler',
#  'Florian Znaniecki',
#  'Irving Zola',
#  'Tukufu Zuberi',
#  'Harriet Zuckerman',
#  'Sharon Zukin',
#  'Theodor W. Adorno',
#  'Aristotle',
#  'Robert Bartholomew',
#  'Frank D. Bean',
#  'Charles Booth ',
#  'Ronald Stuart Burt',
#  'Antonio Caso Andrade',
#  'F. Stuart Chapin',
#  'Nicholas Christakis',
#  'Marquis de Condorcet',
#  'Raewyn Connell',
#  'Anna J. Cooper',
#  'Gøsta Esping-Andersen',
#  'Claude S. Fischer',
#  'Herbert J. Gans',
#  'David W. Garland',
#  'John Goldthorpe',
#  'Andrew Greeley',
#  'David Harvey',
#  'Leonard Hobhouse',
#  'José Ingenieros',
#  'Aleksandr Kapto',
#  'A. L. Kroeber',
#  'Thomas Kuhn',
#  'Michèle Lamont',
#  'Pyotr Lavrov',
#  'Paul Lazarsfeld',
#  'Pierre Guillaume Frédéric le Play',
#  'Henry James Sumner Maine',
#  'Thomas Robert Malthus',
#  'T. H. Marshall',
#  'Tomáš Masaryk',
#  'Carl R. May',
#  'Andrés Molina Enríquez',
#  'Barrington Moore Jr.',
#  'Víctor Nee',
#  'William Fielding Ogburn',
#  'C. J. Pascoe',
#  'Willie Pearson Jr.',
#  'Harriet Presser',
#  'Robert D. Putnam',
#  'Aníbal Quijano',
#  'Alfred Radcliffe-Brown',
#  'Paul Ricœur',
#  'Garry Runciman, 3rd Viscount Runciman of Doxford',
#  'Henri de Saint-Simon',
#  'Joseph Schumpeter',
#  'Anson D. Shupe',
#  'M. N. Srinivas',
#  'Anselm Strauss',
#  'Mark C. Suchman',
#  'Jan Szczepański ',
#  'Ian Taylor ',
#  'Bryan Turner ',
#  'Sudhir Venkatesh',
#  'Duncan J. Watts',
#  'Sidney Webb, 1st Baron Passfield',
#  'Ida B. Wells',
#  'John Adair ',
#  'B. R. Ambedkar',
#  'Giulio Angioni',
#  'Jon Charles Altman',
#  'Talal Asad',
#  'Scott Atran',
#  'Marc Augé',
#  'Nigel Barley ',
#  'Fredrik Barth',
#  'Vasily Bartold',
#  'Keith H. Basso',
#  'Mary Catherine Bateson',
#  'Ruth Behar',
#  'Ruth Benedict',
#  'Dorothy A. Bennett',
#  'Lee R. Berger',
#  'Brent Berlin',
#  'Catherine L. Besteman',
#  'Theodore C. Bestor',
#  'Lewis Binford',
#  'Evelyn Blackwood',
#  'Wilhelm Bleek',
#  'Maurice Bloch',
#  'Anton Blok',
#  'Franz Boas',
#  'Tom Boellstorff',
#  'Paul Bohannan',
#  'Dmitri Bondarenko',
#  'Pere Bosch-Gimpera',
#  'Philippe Bourgois',
#  'Paul Broca',
#  'Christian Bromberger',
#  'Kari Bruwelheide',
#  'Julio Caro Baroja',
#  'Edmund Snow Carpenter',
#  'Napoleon Chagnon',
#  'Pierre Clastres',
#  'Mabel Cook Cole',
#  'Malcolm Carr Collier',
#  'Harold C. Conklin',
#  'Carleton S. Coon',
#  'Frank Hamilton Cushing',
#  'Regna Darnell',
#  'Raymond Dart',
#  'Wade Davis ',
#  'Ernesto de Martino',
#  'Ella Cara Deloria',
#  'Raymond J. DeMallie',
#  'Philippe Descola',
#  'Stanley Diamond',
#  'Cora Du Bois',
#  'Eugene Dubois',
#  'Ann Dunham',
#  'Katherine Dunham',
#  'Elizabeth Cullen Dunn',
#  'Verrier Elwin',
#  'Matthew Engelke',
#  'Arturo Escobar ',
#  'E. E. Evans-Pritchard',
#  'James Ferguson ',
#  'Raymond Firth',
#  'Raymond D. Fogelson',
#  'Meyer Fortes',
#  'Gregory Forth',
#  'Dian Fossey',
#  'Kate Fox',
#  'Robin Fox',
#  'Lina Fruzzetti',
#  'Alfred Gell',
#  'Herb Di Gioia',
#  'Maurice Godelier',
#  'Jane Goodall',
#  'Marjorie Harness Goodwin',
#  'Igor Gorevich',
#  'Harold A. Gould',
#  'David Graeber',
#  'Hilma Granqvist',
#  'J. Patrick Gray',
#  'Marcel Griaule',
#  'Jacob Grimm',
#  'Wilhelm Grimm',
#  'Abdellah Hammoudi',
#  'Michael Harkin',
#  'Michael Harner',
#  'John P. Harrington',
#  'Marvin Harris',
#  'K. David Harrison',
#  'Kirsten Hastrup',
#  'Jacquetta Hawkes',
#  'Stephen C. Headley',
#  'Te Rangi Hīroa',
#  'Arthur Maurice Hocart',
#  'Ian Hodder',
#  'Earnest Hooton',
#  'Ales Hrdlicka',
#  'Eva Verbitsky Hunt',
#  'Dell Hymes',
#  'Bill Irons',
#  'Ira Jacknis',
#  'John M. Janzen',
#  'Thomas Des Jean',
#  'F. Landa Jocano',
#  'Alfred E. Johnson',
#  'William Jones ',
#  'Michal Josephy',
#  'Jeffrey S. Juris',
#  'Sergei Kan',
#  'Jomo Kenyatta',
#  'David Kertzer',
#  'Alice Beck Kehoe',
#  'Anatoly Khazanov',
#  'Eduardo Kohn',
#  'Dorinne K. Kondo',
#  'Charles H. Kraft',
#  'Grover Krantz',
#  'Theodora Kroeber',
#  'Lars Krutak',
#  'Adam Kuper',
#  'George Lakoff',
#  'Harold E. Lambert',
#  'Edmund Leach',
#  'Eleanor Leacock',
#  'Murray Leaf',
#  'Louis Leakey',
#  'Mary Leakey',
#  'Richard Leakey',
#  'Richard Borshay Lee',
#  'Charles Miller Leslie',
#  'Ellen Lewin',
#  'C. Scott Littleton',
#  'Albert Buell Lewis',
#  'Oscar Lewis',
#  'Phillip Harold Lewis',
#  'Iris López',
#  'Robert Lowie',
#  'Alan Macfarlane',
#  'Saba Mahmood',
#  'George E. Marcus',
#  'Jonathan M. Marks',
#  'John Alden Mason',
#  'Michael Atwood Mason',
#  'Phillip McArthur',
#  'Irma McClaurin',
#  'Mervyn Meggitt',
#  'Josef Mengele',
#  'Nicholas Miklouho-Maclay',
#  'Emily Martin ',
#  'Horace Mitchell Miner',
#  'Sidney Mintz',
#  'Ashley Montagu',
#  'James Mooney',
#  'John H. Moore',
#  'Lewis H. Morgan',
#  'Desmond Morris',
#  'George Murdock',
#  'Yolanda Murphy',
#  'Laura Nader',
#  'Moni Nag',
#  'Jeremy Narby',
#  'Raoul Naroll',
#  'Erland Nordenskiöld',
#  'Gananath Obeyesekere',
#  "Kaori O'Connor",
#  'Aihwa Ong',
#  'Marvin Opler',
#  'Morris Opler',
#  'Sherry Ortner',
#  'Keith F. Otterbein',
#  'Elsie Clews Parsons',
#  'Thomas J. Pluckhahn',
#  'Hortense Powdermaker',
#  'Harald E.L. Prins',
#  'Buell Quain',
#  'James Quesada',
#  'Paul Rabinow',
#  'Wilhelm Radloff',
#  'Lucinda Ramberg',
#  'Roy Rappaport',
#  'Hans Ras',
#  'Gerardo Reichel-Dolmatoff',
#  'Kathy Reichs',
#  'Audrey Richards',
#  'W. H. R. Rivers',
#  'Paul Rivet',
#  'Joel Robbins',
#  'Renato Rosaldo',
#  'Gayle Rubin',
#  'Robert A. Rubinstein',
#  'Marshall Sahlins',
#  'Noel B. Salazar',
#  'Roger Sandall',
#  'Edward Sapir',
#  'Patricia Sawin',
#  'Nancy Scheper-Hughes',
#  'Wilhelm Schmidt ',
#  'Tobias Schneebaum',
#  'James C. Scott',
#  'Thayer Scudder',
#  'Elman Service',
#  'Afanasy Shchapov',
#  'Gerald F. Schroedl',
#  'Florence Connolly Shipek',
#  'Sydel Silverman',
#  'Cathy Small',
#  'Christen A. Smith',
#  'Jacques Soustelle',
#  'Melford Spiro',
#  'James Spradley',
#  'Julian Steward',
#  'Marilyn Strathern',
#  'William Sturtevant',
#  'Niara Sudarkasa',
#  'Michael Taussig',
#  'Colin Turnbull',
#  'Bruce Trigger',
#  'Karl Verner',
#  'L. P. Vidyarthi',
#  'Eduardo Viveiros de Castro',
#  'Christoph von Fürer-Haimendorf',
#  'Anthony F. C. Wallace',
#  'Lee Henderson Watkins',
#  ...]

# %%
''' Extract links '''
field_dict  = {key:[] for key in science_dict.values()} # {field:empty-list}
for name, field in science_dict.items():
    with open(f'wiki_content/{name}','r', encoding = 'utf-8') as f:
        txt = f.read()
# Out:
#   File "<ipython-input-7-b3646ec2ab95>", line 2
#     field_dict  = {key:[] for science_dict.keys()}
#                                                  ^
# SyntaxError: invalid syntax

# %%
# We define function for the tf-idf - we use them through the assignment

''' Used throughout the assignment '''
def sort_dict(_dict):
    return (dict(sorted(_dict.items(), key=lambda x:x[1], reverse = True)))

''' We set up the needed functions: TC, TF and IDF + A preprocessing function '''
def _TC(_tokens):
    ''' Returns a dict with words as keys and their frequency in the document as values '''
    unique_words = set(_tokens) # unique words
    freq_dict = dict.fromkeys(unique_words, 0) # empty dict with each unique word as key and with val=0
    for word in _tokens:
        freq_dict[word] += 1 # count the words 
    return freq_dict


def computeTF(_tokens):
    ''' Input is a tokenized document. 
    Output is a dict with unique words, sorted by TF in descending order '''
    bagOfWords = _TC(_tokens) # call BoW/TC function
    tfDict = {} 
    bagOfWordsCount = sum(bagOfWords.values()) # count number of words = sum of the frequencies 
    for word, count in bagOfWords.items(): # loop over the words and their frequnecy
        tfDict[word] = count / float(bagOfWordsCount)
    # Sort based on TF-value
    return sort_dict(tfDict)

def computeIDF(documents):
    ''' The input should be a dictionary where the keys are the documents and the values
    are the tokenized content belonging to the documents '''
    N = len(documents) # count number of documents 
    vocab = set([_w for _race, txt in documents.items() for _w in txt]) # Get the entire vocab from all docs
    idfDict = dict.fromkeys(vocab, 0) # dict with words as keys and count/val set to 0

    for document, txt in documents.items(): # loop over the documents/keys and their content/values
        _bow = _TC(txt) # create bag_of_words/TC for the document
        for word, val in _bow.items(): # loop over every unique word in the document 
            idfDict[word] += 1 # increment by one, for each document the word appears in 
            
    # for all the words in the vocab/corpus and the number documents they appear in 
    for word, val in idfDict.items(): 
        idfDict[word] = math.log(N / float(val)) # calculate the idf for each word 
    return idfDict

def calc_tf_idf(document_content_dict, tc_instead = False):
    ''' The input should be a dictionary where the keys are the documents and the values
    are the tokenized content belonging to the documents '''
     # get vocab across all documents 
    vocab = set([_w for _com, txt in document_content_dict.items() for _w in txt])
    _idf = computeIDF(document_content_dict) # compute idf of the documents 
    tf_idf_list = [] # list to append lists of tf_ids's to, for each community
    for _com, _txt in document_content_dict.items(): # loop over the documents 
        com_tf = computeTF(_txt) # calc the com's tf 
        if tc_instead:
            com_tf = _TC(_txt) # if the TC is needed instead of the TF
        
        # loop over the words in the communities vocab
        # if the word is in the com_corpus, calc tf_idf - otherwise return 0 
        tf_idf = [_idf[_w] * com_tf[_w] if _w in com_tf.keys() else 0 for _w in vocab]
        tf_idf_list += [tf_idf] # append the row --> one row for each race      

    # Create tf_idf df (or tc_idf, if that was chosen)
    tf_idf_df = pd.DataFrame(tf_idf_list,
                             index=document_content_dict.keys(),
                             columns = set([_w for _com, txt in document_content_dict.items()\
                                            for _w in txt])).transpose() # transpose 
    if tc_instead:
        return round(tf_idf_df) # round to nearest whole number
    return tf_idf_df

def preprocess(text, remove_stopwords=True):
    import nltk
    import string 
    from nltk.corpus import stopwords

    # import stopwords
    stop_words_list = stopwords.words("english")

     # 1) Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))

    if remove_stopwords:
        # 2) Remove stopwords and tokenize
        tokens = [token for token in nltk.word_tokenize(text.lower()) if token not in stop_words_list]
    else:
        # 2) Tokenize
        tokens = [token for token in nltk.word_tokenize(text.lower())]

    # 3) Lammetize = convert words to their root (running -> run)
    wnl = nltk.WordNetLemmatizer() 
    lemmas = [wnl.lemmatize(t) for t in tokens] 
    return lemmas # return a list of stems/lemmas

# %%
char_list = list(map(lambda x: x.split(' (')[0], df_characters.Name))
char_low = list(map(lambda x: x.lower(), char_list)) # lowercase the names
char_list += char_low + ['Cherry','cherry'] # extend lower and uppercase list
char_list = list(set(char_list)) # if duplicates
 # get the longer names first - prioritise those matches e.g. "Hinox" over "Hino" (regex's are sequentially ordered/prioritized)
char_list = sorted(char_list, key = len, reverse=True)

''' Makes another version where the races are excluded'''
race_list = list(set(df_characters.Race)) # remove duplicates 
race_low = list(map(lambda x: x.lower(), race_list)) # lowercase the names
race_list += char_list + race_low # extend lower and uppercase list
race_list = list(set(race_list)) # if duplicates
 # get the longer names first - prioritise those matches e.g. "Hinox" over "Hino" (regex's are sequentially ordered/prioritized)
race_list = sorted(race_list, key = len, reverse=True)

#### Regex search to replace characternames with '' 
# The regex search - remove genetive case, plural and if there are partheses like "Stone Talon (Senior)"
_s = r"(?:(?: )?\((?:.*?)?\))?(?:s|'s|'|es)?|\b".join(char_list)+"(?:(?: )?\((?:.*?)?\))?(?:s|'s|'|es)?"

if inc_race:
    _s = r"(?:(?: )?\((?:.*?)?\))?(?:s|'s|'|es)?|\b".join(race_list)+"(?:(?: )?\((?:.*?)?\))?(?:s|'s|'|es)?"

''' Make a dict with the structure: {community:content}'''
com_txt_dict = {com:[] for com in (set(x[0] for x in com_node_list))} # dict to append to with communities as keys 
for _com,_name in tqdm(com_node_list): # loop over the com,nodes the text files 
    with open(f"character_txt/{_name.replace(' ','_')}.txt", 'r', encoding='utf-8') as f: # read file
        clean_text = re.sub(r"=(?:=)?(?:.*?)=(?:=)?", '', f.read()) # remove those "== XX =="-things
        clean_text = re.sub(_s, '', clean_text) # remove character names + plural + genitive case 
        clean_text = preprocess(clean_text) # preprocess
        com_txt_dict[_com] += clean_text # update to com-dicts with content from their nodes

# %%
onlyfiles
# Out:
# ['A._Doak_Barnett.txt',
#  'A._F._K._Organski.txt',
#  'A._H._J._Prins.txt',
#  'A._L._Kroeber.txt',
#  'A._Ronald_Gallant.txt',
#  'Aaron_Antonovsky.txt',
#  'Aaron_Belkin.txt',
#  'Aaron_Cicourel.txt',
#  'Aaron_Wildavsky.txt',
#  'Abba_P._Lerner.txt',
#  'Abdelkebir_Khatibi.txt',
#  'Abdellah_Hammoudi.txt',
#  'Abdul_Razzaq_Kemal.txt',
#  'Abhijit_Banerjee.txt',
#  'Abraham_Maslow.txt',
#  'Abraham_Moles.txt',
#  'Abraham_Robinson.txt',
#  'Adair_Turner,_Baron_Turner_of_Ecchinswell.txt',
#  'Adam_Berinsky.txt',
#  'Adam_Kuper.txt',
#  'Adam_Possamai.txt',
#  'Adam_Przeworski.txt',
#  'Adam_Smith.txt',
#  'Adelbert_Ames_Jr..txt',
#  'Adeolu_Akande.txt',
#  'Adil_Abdul-Mahdi.txt',
#  'Adolphe_Quetelet.txt',
#  'Adolphus_G._Belk_Jr..txt',
#  'Adolph_Wagner.txt',
#  'Adrian_Furnham.txt',
#  'Adria_Lawrence.txt',
#  'Afanasy_Shchapov.txt',
#  'Agustin_Cueva.txt',
#  'Agustín_Carstens.txt',
#  'Ahron_Bregman.txt',
#  'Aihwa_Ong.txt',
#  'Ajay_Chhibber.txt',
#  'Akiyoshi_Kitaoka.txt',
#  'Alain_Ehrenberg.txt',
#  'Alain_Touraine.txt',
#  'Alan_Abramowitz.txt',
#  'Alan_Baddeley.txt',
#  'Alan_Blinder.txt',
#  'Alan_Bock.txt',
#  'Alan_Budd.txt',
#  'Alan_E._Kazdin.txt',
#  'Alan_Greenspan.txt',
#  'Alan_Manning.txt',
#  'Alan_S._Kaufman.txt',
#  'Alasdair_Smith.txt',
#  'Alberto_Alesina.txt',
#  'Albert_Bandura.txt',
#  'Albert_Benschop.txt',
#  'Albert_Bergstrom.txt',
#  'Albert_Buell_Lewis.txt',
#  'Albert_Ellis.txt',
#  'Albert_J._Meyer_(economist).txt',
#  'Albert_Nalchajyan.txt',
#  'Albert_Schäffle.txt',
#  'Albion_Woodbury_Small.txt',
#  'Alcira_Argumedo.txt',
#  'Alejandro_Portes.txt',
#  'Alejandro_Toledo.txt',
#  'Aleksandr_Kapto.txt',
#  'Alexander_Deichsel.txt',
#  'Alexander_Luria.txt',
#  'Alexander_Sachs.txt',
#  'Alexander_Tarasov.txt',
#  'Alexander_Van_der_Bellen.txt',
#  'Alexander_Wendt.txt',
#  'Alexis_de_Tocqueville.txt',
#  'Alex_Tabarrok.txt',
#  'Alfons_Vansteenwegen.txt',
#  'Alfred_Adler.txt',
#  'Alfred_Binet.txt',
#  'Alfred_D._Chandler_Jr..txt',
#  'Alfred_E._Johnson.txt',
#  'Alfred_Eichner.txt',
#  'Alfred_Gell.txt',
#  'Alfred_H._Conrad.txt',
#  'Alfred_Jules_Émile_Fouillée.txt',
#  'Alfred_Marshall.txt',
#  'Alfred_R._Lindesmith.txt',
#  'Alfred_Radcliffe-Brown.txt',
#  'Alfred_Stepan.txt',
#  'Alice_Beck_Kehoe.txt',
#  'Alice_Kang.txt',
#  'Alice_Miller_(psychologist).txt',
#  'Alice_Rivlin.txt',
#  'Ali_ibn_Sahl_Rabban_al-Tabari.txt',
#  'Ali_M._El-Agraa.txt',
#  'Ali_Shariati.txt',
#  'Allan_Paivio.txt',
#  'Allan_Schnaiberg.txt',
#  'Allison_Stanger.txt',
#  'Allyn_Abbott_Young.txt',
#  'Alon_Ben-Meir.txt',
#  'Aloysius-Michaels_Nnabugwu_Okolie.txt',
#  'Alva_Myrdal.txt',
#  'Alvin_E._Roth.txt',
#  'Alvin_Gouldner.txt',
#  'Alvin_Wolfe.txt',
#  'Alwyn_Young.txt',
#  'Amartya_Sen.txt',
#  'Amelia_Fletcher.txt',
#  'Amin_Maalouf.txt',
#  'Ammar_Bouhouche.txt',
#  'Amos_Tversky.txt',
#  'Amrita_Basu.txt',
#  'Amrita_Narlikar.txt',
#  'Amy_Finkelstein.txt',
#  'Amy_Gutmann.txt',
#  'Amy_Mazur.txt',
#  'Anatoly_Khazanov.txt',
#  'Andreas_Löschel.txt',
#  'Andrei_Shleifer.txt',
#  'Andrew_Arato.txt',
#  'Andrew_Bacevich.txt',
#  'Andrew_Greeley.txt',
#  'Andrew_Hughes_Hallett.txt',
#  'Andrew_Lo.txt',
#  'Andrew_Milner.txt',
#  'Andrew_Moravcsik.txt',
#  'Andrew_N._Meltzoff.txt',
#  'Andrew_Oswald.txt',
#  'Andrew_Pickering.txt',
#  'Andrew_Sentance.txt',
#  'Andrey_Korotayev.txt',
#  'Andre_Beteille.txt',
#  'Andre_Gunder_Frank.txt',
#  'Andrzej_Sławiński.txt',
#  'Andrés_Molina_Enríquez.txt',
#  'Angus_Deaton.txt',
#  'Aninhalli_Vasavi.txt',
#  'Ankur_Pare.txt',
#  'Anna_Freud.txt',
#  'Anna_Gifty_Opoku-Agyeman.txt',
#  'Anna_Grzymala.txt',
#  'Anna_J._Cooper.txt',
#  'Anna_Schwartz.txt',
#  'Anne-Marie_Slaughter.txt',
#  'Annette_Baker_Fox.txt',
#  'Anne_Carter_(economist).txt',
#  'Anne_Osborn_Krueger.txt',
#  'Anne_Robert_Jacques_Turgot.txt',
#  'Anne_Treisman.txt',
#  'Annie_Marion_MacLean.txt',
#  'Ann_Dunham.txt',
#  'Ann_Mische.txt',
#  'Ann_Swidler.txt',
#  'Anselm_Strauss.txt',
#  'Anson_D._Shupe.txt',
#  'Anthony_Downs.txt',
#  'Anthony_F._C._Wallace.txt',
#  'Anthony_Giddens.txt',
#  'Anthony_Ludovici.txt',
#  'Anthony_Saunders.txt',
#  'Anthony_Venables.txt',
#  'Antoaneta_Vassileva.txt',
#  'Antoine_Augustin_Cournot.txt',
#  'Antonina_Kłoskowska.txt',
#  'Antonio_Caso_Andrade.txt',
#  'Antonio_Gramsci.txt',
#  'Antonio_Negri.txt',
#  'Antoni_Kępiński.txt',
#  'Antony_Davies.txt',
#  'Anton_Blok.txt',
#  'Anu_Muhammad.txt',
#  'Anuška_Ferligoj.txt',
#  'Anwar_Shaikh_(economist).txt',
#  'Aníbal_Cavaco_Silva.txt',
#  'Aníbal_Quijano.txt',
#  'Aquila_Berlas_Kiani.txt',
#  'Archon_Fung.txt',
#  'Arend_Lijphart.txt',
#  'Ariel_Rubinstein.txt',
#  'Aristotle.txt',
#  'Arjun_Appadurai.txt',
#  'Armando_Di_Filippo.txt',
#  'Armand_Peschard-Sverdrup.txt',
#  'Armen_Alchian.txt',
#  'Armindo_Freitas-Magalhães.txt',
#  'Armin_Falk.txt',
#  'Arnold_Gehlen.txt',
#  'Arnold_Harberger.txt',
#  'Arnold_Marshall_Rose.txt',
#  'Arnold_Mindell.txt',
#  'Arnold_Plant.txt',
#  'Arnold_Wolfers.txt',
#  'Arnold_Zellner.txt',
#  'Aron_K._Barbey.txt',
#  'Arthur_Cecil_Pigou.txt',
#  'Arthur_F._Bentley.txt',
#  'Arthur_J._Bachrach.txt',
#  'Arthur_Jensen.txt',
#  'Arthur_Kornhauser.txt',
#  'Arthur_Laffer.txt',
#  'Arthur_Maurice_Hocart.txt',
#  'Arthur_Melvin_Okun.txt',
#  'Arthur_Naftalin.txt',
#  'Arthur_Salz.txt',
#  'Arthur_Seldon.txt',
#  'Arthur_Young_(agriculturist).txt',
#  'Arturo_Escobar_(anthropologist).txt',
#  'Arturo_Porzecanski.txt',
#  'Artyom_Shneyerov.txt',
#  'Arun_Agrawal.txt',
#  'Arun_Sundararajan.txt',
#  "As'ad_AbuKhalil.txt",
#  'Asher_Arian.txt',
#  'Asher_Cohen.txt',
#  'Asher_Tishler.txt',
#  'Ashis_Nandy.txt',
#  'Ashley_E._Jardina.txt',
#  'Ashley_Montagu.txt',
#  'Assar_Lindbeck.txt',
#  'Atilla_Yayla.txt',
#  'Attahiru_Jega.txt',
#  'Attilio_Celant.txt',
#  'Audrey_Richards.txt',
#  'Auguste_Comte.txt',
#  'Augustus_John_Rush.txt',
#  'August_Friedrich_Wilhelm_Crome.txt',
#  'Austan_Goolsbee.txt',
#  'Austin_Robinson.txt',
#  'Austin_Sarat.txt',
#  'Aušra_Augustinavičiūtė.txt',
#  'Averroes.txt',
#  'Aviad_Raz.txt',
#  'Avinash_Dixit.txt',
#  'Avishay_Braverman.txt',
#  'Axel_Honneth.txt',
#  'Axel_Leijonhufvud.txt',
#  'Ayesha_Jalal.txt',
#  'B._Anthony_Bogues.txt',
#  'B._F._Skinner.txt',
#  'B._R._Ambedkar.txt',
#  'Baidyanath_Misra.txt',
#  'Barbara_Bergmann.txt',
#  'Barbara_Fredrickson.txt',
#  'Barbara_Geddes.txt',
#  'Barbara_J._Spencer.txt',
#  'Barbara_Rothbaum.txt',
#  'Barney_Glaser.txt',
#  'Barrington_Moore_Jr..txt',
#  'Barry_B._Levine.txt',
#  'Barry_Bluestone.txt',
#  'Barry_Eichengreen.txt',
#  'Barry_Glassner.txt',
#  'Barry_Wellman.txt',
#  'Baruch_Kimmerling.txt',
#  'Basil_Yamey.txt',
#  'Beatrice_Webb.txt',
#  'Beatrice_Weder_di_Mauro.txt',
#  'Beatriz_Magaloni.txt',
#  'Benedict_Anderson.txt',
#  'Bengt_Holmström.txt',
#  'Benjamin_Barber.txt',
#  'Benjamin_Cohen_(political_economist).txt',
#  'Benjamin_Diokno.txt',
#  'Benjamin_Ginsberg_(political_scientist).txt',
#  'Benjamin_Graham.txt',
#  'Benjamin_Lee_Whorf.txt',
#  'Benjamin_M._Friedman.txt',
#  'Benjamin_Strong_Jr..txt',
#  'Benjamin_Zablocki.txt',
#  'Bennett_McCallum.txt',
#  'Benton_Johnson.txt',
#  'Ben_Bernanke.txt',
#  'Ben_Kerkvliet.txt',
#  'Bernardo_Kliksberg.txt',
#  'Bernardo_Sorj.txt',
#  'Bernard_Lonergan.txt',
#  'Bernard_van_Praag.txt',
#  'Bernie_Fraser_(economist).txt',
#  'Bertell_Ollman.txt',
#  'Bertil_Ohlin.txt',
#  'Bertram_Gawronski.txt',
#  'Bertrand_de_Jouvenel.txt',
#  'Bethany_Albertson.txt',
#  'Bethany_Barratt.txt',
#  'Beth_A._Simmons.txt',
#  'Betty_Glad.txt',
#  'Bibb_Latané.txt',
#  'Bill_Avery.txt',
#  "Bill_O'Hanlon.txt",
#  'Bingu_wa_Mutharika.txt',
#  'Bluma_Zeigarnik.txt',
#  'Boaventura_de_Sousa_Santos.txt',
#  'Bogdan_Denitch.txt',
#  'Bohdan_Hawrylyshyn.txt',
#  'Bolaji_Akinyemi.txt',
#  'Boris_Kagarlitsky.txt',
#  'Boyan_Jovanovic.txt',
#  'Brad_W._Setser.txt',
#  'Branko_Horvat.txt',
#  "Brendan_O'Leary.txt",
#  'Brenda_Milner.txt',
#  'Brent_Berlin.txt',
#  'Brian_Butterworth.txt',
#  'Brian_Knutson.txt',
#  'Brian_Massumi.txt',
#  'Brian_Wesbury.txt',
#  'Brigitte_L._Nacos.txt',
#  'Bronisław_Malinowski.txt',
#  'Bronisław_Piłsudski.txt',
#  'Brooke_Ackerly.txt',
#  'Bruce_A._Williams.txt',
#  'Bruce_Bueno_de_Mesquita.txt',
#  'Bruce_Hood_(psychologist).txt',
#  'Bruce_Kingma.txt',
#  'Bruce_Trigger.txt',
#  'Bruno_Frey.txt',
#  'Bruno_Latour.txt',
#  'Bryan_Caplan.txt',
#  'Bryan_Turner_(sociologist).txt',
#  'Buell_Quain.txt',
#  'Burton_Malkiel.txt',
#  'Burton_Weisbrod.txt',
#  'Bärbel_Inhelder.txt',
#  'C._Arden_Pope.txt',
#  'C._Christine_Fair.txt',
#  'C._Fred_Bergsten.txt',
#  'C._J._Pascoe.txt',
#  'C._Lloyd_Morgan.txt',
#  'C._Scott_Littleton.txt',
#  'C._Wright_Mills.txt',
#  'Calvin_Veltman.txt',
#  'Camilla_Wedgwood.txt',
#  'Campbell_Harvey.txt',
#  'Carleton_S._Coon.txt',
#  'Carlos_A._Vegh.txt',
#  'Carlos_Manuel_Urzúa_Macías.txt',
#  'Carl_Brigham.txt',
#  'Carl_Brinkmann.txt',
#  'Carl_E._Walsh.txt',
#  'Carl_J._Couch.txt',
#  'Carl_Jung.txt',
#  'Carl_Levy_(political_scientist).txt',
#  'Carl_Menger.txt',
#  'Carl_R._May.txt',
#  'Carl_Rogers.txt',
#  'Carl_Stumpf.txt',
#  'Carmen_Reinhart.txt',
#  'Carole_Joffe.txt',
#  'Carolyn_Heinrich.txt',
#  'Carol_Corrado.txt',
#  'Carol_Gilligan.txt',
#  'Carol_M._Swain.txt',
#  'Cary_Cooper.txt',
#  'Catharine_Cox_Miles.txt',
#  'Catherine_Berndt.txt',
#  'Catherine_Boone.txt',
#  'Catherine_Tucker.txt',
#  'Cathryn_Clüver_Ashbrook.txt',
#  'Cathy_Small.txt',
#  'Cecilia_Rouse.txt',
#  'Cecil_R._Reynolds.txt',
#  'Celia_Stopnicka_Heller.txt',
#  'Celinda_Lake.txt',
#  'Celso_Furtado.txt',
#  'Chalmers_Johnson.txt',
#  'Chantal_Mouffe.txt',
#  'Charles_A._Holt.txt',
#  'Charles_Beitz.txt',
#  'Charles_Booth_(social_reformer).txt',
#  'Charles_Cooley.txt',
#  'Charles_Davenant.txt',
#  'Charles_E._Osgood.txt',
#  'Charles_E._Silberman.txt',
#  'Charles_Fourier.txt',
#  'Charles_Gide.txt',
#  'Charles_Goodhart.txt',
#  'Charles_H._McNutt.txt',
#  'Charles_Hall_(economist).txt',
#  'Charles_Horioka.txt',
#  'Charles_Kennedy_(economist).txt',
#  'Charles_Knickerbocker_Harley.txt',
#  'Charles_Kurzman.txt',
#  'Charles_Lemert.txt',
#  'Charles_Manski.txt',
#  'Charles_Miller_Leslie.txt',
#  'Charles_Murray_(political_scientist).txt',
#  'Charles_O._Jones.txt',
#  'Charles_Plott.txt',
#  'Charles_R._Adrian.txt',
#  'Charles_Samuel_Myers.txt',
#  'Charles_Spearman.txt',
#  'Charles_Tilly.txt',
#  'Charles_W._Mills.txt',
#  'Charles_Wolf_Jr..txt',
#  'Charlie_Bean_(economist).txt',
#  'Charlotte_Perkins_Gilman.txt',
#  'Cheryl_Schonhardt-Bailey.txt',
#  'Cheves_Perky.txt',
#  'Christen_A._Smith.txt',
#  'Christian_Bromberger.txt',
#  'Christian_Gostečnik.txt',
#  'Christian_Gouriéroux.txt',
#  'Christian_Hellwig.txt',
#  'Christian_Smith_(sociologist).txt',
#  'Christina_Paxson.txt',
#  'Christina_Romer.txt',
#  'Christine_Delphy.txt',
#  'Christopher_A._Pissarides.txt',
#  'Christopher_Coyne_(professor).txt',
#  'Christopher_Freeman.txt',
#  'Christopher_Hood.txt',
#  'Christopher_J._Hill.txt',
#  'Christopher_Peterson_(psychologist).txt',
#  'Christopher_Thornberg.txt',
#  'Christopher_Winship.txt',
#  'Christoph_M._Schmidt.txt',
#  'Christoph_von_Fürer-Haimendorf.txt',
#  'Chris_Blattman.txt',
#  'Chris_Hatcher_(psychologist).txt',
#  'Chris_William_Sanchirico.txt',
#  'Clair_Wilcox.txt',
#  'Clara_Stern.txt',
#  'Clarence_Edwin_Ayres.txt',
#  'Clarissa_Rile_Hayward.txt',
#  'Clark_A._Murdock.txt',
#  'Clark_L._Hull.txt',
#  'Clark_Wissler.txt',
#  'Claude_Lévi-Strauss.txt',
#  'Claude_S._Fischer.txt',
#  'Claudia_Goldin.txt',
#  'Claudia_López_Hernández.txt',
#  'Claudia_Sahm.txt',
#  'Claus_Offe.txt',
#  'Clifford_Clogg.txt',
#  'Clifford_Geertz.txt',
#  'Cliff_Asness.txt',
#  'Clinton_Rossiter.txt',
#  'Clive_Granger.txt',
#  'Clyde_Coombs.txt',
#  'Clyde_V._Prestowitz_Jr..txt',
#  'Colin_Camerer.txt',
#  'Colin_Clark_(economist).txt',
#  'Colin_Crouch.txt',
#  'Colin_Hay_(political_scientist).txt',
#  'Colin_S._Gray.txt',
#  'Colin_Talbot.txt',
#  'Colin_Turnbull.txt',
#  'Condoleezza_Rice.txt',
#  'Connel_Fullenkamp.txt',
#  'Conrad_Phillip_Kottak.txt',
#  'Cora_Du_Bois.txt',
#  'Cordelia_Fine.txt',
#  'Cornelius_Castoriadis.txt',
#  'Cornelius_M._Kerwin.txt',
#  "Cornelius_O'Leary.txt",
#  'Corrado_Gini.txt',
#  'Craig_Calhoun.txt',
#  'Crystal_Marie_Fleming.txt',
#  'Cuno_Pümpin.txt',
#  'Cynthia_Enloe.txt',
#  'Daisy_Bates_(author).txt',
#  'Dale_W._Jorgenson.txt',
#  'Dambisa_Moyo.txt',
#  'Danielle_Allen.txt',
#  'Danielle_Bleitrach.txt',
#  'Daniel_Batson.txt',
#  'Daniel_Bell.txt',
#  'Daniel_Benjamin.txt',
#  'Daniel_David.txt',
#  'Daniel_Deudney.txt',
#  'Daniel_Ellsberg.txt',
#  'Daniel_Foss.txt',
#  'Daniel_Gilbert_(psychologist).txt',
#  'Daniel_J._Elazar.txt',
#  'Daniel_Kahneman.txt',
#  'Daniel_Levy_(sociologist).txt',
#  'Daniel_McFadden.txt',
#  'Daniel_P._Aldrich.txt',
#  'Daniel_P._Franklin.txt',
#  'Daniel_Patrick_Moynihan.txt',
#  'Daniel_Raymond.txt',
#  'Daniel_Reisberg.txt',
#  'Daniel_S._Hamermesh.txt',
#  'Daniel_Schacter.txt',
#  'Daniel_Trefler.txt',
#  'Daniel_W._Drezner.txt',
#  'Dani_Rodrik.txt',
#  'Danièle_Hervieu-Léger.txt',
#  'Dankwart_Danckwerts.txt',
#  'Danny_Jorgensen.txt',
#  'Danny_Quah.txt',
#  'Danny_Williams_(politician).txt',
#  'Dan_Ariely.txt',
#  'Dan_Johnson_(economist).txt',
#  'Dan_P._McAdams.txt',
#  'Dan_Reiter.txt',
#  'Dara_Strolovitch.txt',
#  'Darnell_Hawkins.txt',
#  'Daron_Acemoglu.txt',
#  'Darrell_M._West.txt',
#  'David_A._Jaeger.txt',
#  'David_A._Snow.txt',
#  'David_Adamany.txt',
#  'David_Apter.txt',
#  'David_B._Audretsch.txt',
#  'David_Bloor.txt',
#  'David_Bositis.txt',
#  'David_Boyle_(author).txt',
#  'David_Buss.txt',
#  'David_Butler_(psephologist).txt',
#  'David_C._Lane.txt',
#  'David_C._Mowery.txt',
#  'David_C._Stark.txt',
#  'David_Card.txt',
#  'David_Cass.txt',
#  'David_D._Friedman.txt',
#  'David_Dodd.txt',
#  'David_E._Meyer.txt',
#  'David_Easton.txt',
#  'David_F._Duncan.txt',
#  'David_F._Gordon.txt',
#  'David_Fellman.txt',
#  'David_Forbes_Hendry.txt',
#  'David_G._Bromley.txt',
#  'David_Gale.txt',
#  'David_Glass_(sociologist).txt',
#  'David_Graeber.txt',
#  'David_H._Bayley.txt',
#  'David_Harvey.txt',
#  'David_Hume.txt',
#  'David_J._Jackson.txt',
#  'David_James_Davies.txt',
#  'David_Kertzer.txt',
#  'David_Laibson.txt',
#  'David_Laidler.txt',
#  'David_Lewis_(psychologist).txt',
#  'David_Lockwood_(sociologist).txt',
#  'David_M._Barrett.txt',
#  'David_M._Kreps.txt',
#  'David_Marsh_(political_scientist).txt',
#  'David_McClelland.txt',
#  'David_McNeill.txt',
#  'David_McWilliams_(economist).txt',
#  'David_Miles.txt',
#  'David_Miller_(political_theorist).txt',
#  'David_Neumark.txt',
#  'David_Newbery.txt',
#  'David_Nolan_(politician).txt',
#  'David_R._Mayhew.txt',
#  'David_Ricardo.txt',
#  'David_Romer.txt',
#  'David_Rumelhart.txt',
#  'David_S._Rohde.txt',
#  'David_Samuels_(political_scientist).txt',
#  'David_Shapiro_(economist).txt',
#  'David_Tzuriel.txt',
#  'David_W._Brady.txt',
#  'David_W._Garland.txt',
#  'David_Wechsler.txt',
#  'Dean_Karlan.txt',
#  'Debapriya_Bhattacharya.txt',
#  'Deborah_Avant.txt',
#  'Debraj_Ray_(economist).txt',
#  'Deirdre_Barrett.txt',
#  'Deirdre_McCloskey.txt',
#  'Dell_Hymes.txt',
#  'Denise_Walsh.txt',
#  'Denis_Duclos.txt',
#  'Dennis_F._Thompson.txt',
#  'Dennis_Kavanagh.txt',
#  'Dennis_Marsden.txt',
#  'Dennis_Robertson_(economist).txt',
#  'Dennis_Snower.txt',
#  'Dermot_Barnes-Holmes.txt',
#  'Desmond_Morris.txt',
#  'Diana_Baumrind.txt',
#  'Diana_Mutz.txt',
#  'Dianne_Pinderhughes.txt',
#  'Dian_Fossey.txt',
#  'Diego_Abad_de_Santillán.txt',
#  'Diego_Gambetta.txt',
#  'Dieter_Claessens.txt',
#  'Dietrich_Dörner.txt',
#  'Dimitrie_Gusti.txt',
#  'Dimitri_Uznadze.txt',
#  'Dina_Pomeranz.txt',
#  'Dipankar_Gupta.txt',
#  'Dirk_Helbing.txt',
#  'Dirk_Kaesler.txt',
#  'Dmitri_Bondarenko.txt',
#  'Domingo_Laíno.txt',
#  'Dominique_Guellec.txt',
#  'Donald_Andrews.txt',
#  'Donald_Angus_MacKenzie.txt',
#  'Donald_Black_(sociologist).txt',
#  'Donald_Broadbent.txt',
#  'Donald_Downs.txt',
#  'Donald_E._Stokes.txt',
#  'Donald_Green.txt',
#  'Donald_Harding_(professor).txt',
#  'Donald_John_Roberts.txt',
#  'Donald_L._Horowitz.txt',
#  'Donald_MacDougall.txt',
#  'Donald_O._Hebb.txt',
#  'Donald_T._Campbell.txt',
#  'Donald_Winnicott.txt',
#  'Donata_Francescato.txt',
#  'Donatella_della_Porta.txt',
#  'Donna_Haraway.txt',
#  'Donna_Lee_Bowen.txt',
#  'Donna_Shalala.txt',
#  'Don_Norman.txt',
#  'Don_Patinkin.txt',
#  'Dora_L._Costa.txt',
#  'Dorceta_Taylor.txt',
#  'Doreen_Kimura.txt',
#  'Dorinne_K._Kondo.txt',
#  'Doris_Fuchs_(scientist).txt',
#  'Doris_Graber.txt',
#  'Dorothy_A._Bennett.txt',
#  'Dorothy_E._Smith.txt',
#  'Dorothy_Wedderburn.txt',
#  'Douglass_North.txt',
#  'Douglas_Diamond.txt',
#  'Douglas_E._Cowan.txt',
#  'Douglas_Irwin.txt',
#  'Douglas_Peters.txt',
#  'Douglas_R._White.txt',
#  'Douglas_Vakoch.txt',
#  'Douglas_W._Rae.txt',
#  'Drew_Fudenberg.txt',
#  'Drew_Halfmann.txt',
#  'Drew_Westen.txt',
#  'Dudley_North_(economist).txt',
#  'Duncan_Black.txt',
#  'Duncan_J._Watts.txt',
#  'Dwayne_Benjamin.txt',
#  'E._Adamson_Hoebel.txt',
#  'E._Digby_Baltzell.txt',
#  'E._E._Evans-Pritchard.txt',
#  'E._F._Schumacher.txt',
#  'E._H._Carr.txt',
#  'E._P._Thompson.txt',
#  'E._Wight_Bakke.txt',
#  'Earl_Black.txt',
#  'Edgar_Anstey_(psychologist).txt',
#  'Edgar_Schein.txt',
#  'Edith_Abbott.txt',
#  'Edith_Penrose.txt',
#  'Edmond_Keller.txt',
#  'Edmond_Malinvaud.txt',
#  'Edmund_Bourne.txt',
#  'Edmund_Burke.txt',
#  'Edmund_Leach.txt',
#  'Edmund_Phelps.txt',
#  'Edmund_Snow_Carpenter.txt',
#  'Edmund_Wnuk-Lipinski.txt',
#  'Edna_B._Foa.txt',
#  'Eduardo_Viveiros_de_Castro.txt',
#  'Eduard_Bernstein.txt',
#  'Edvard_Westermarck.txt',
#  'Edvin_Kanka_Ćudić.txt',
#  'Edward_Beiser.txt',
#  'Edward_Burnett_Tylor.txt',
#  'Edward_C._Banfield.txt',
#  'Edward_C._Prescott.txt',
#  'Edward_C._Tolman.txt',
#  'Edward_Chamberlin.txt',
#  'Edward_E._Leamer.txt',
#  'Edward_Glaeser.txt',
#  'Edward_Lawrence_Wheelwright.txt',
#  'Edward_Sapir.txt',
#  'Edward_Shils.txt',
#  'Edward_Szczepanik.txt',
#  'Edward_Thorndike.txt',
#  'Edward_Wolff.txt',
#  'Edwin_Amenta.txt',
#  'Edwin_Cannan.txt',
#  'Edwin_Holt.txt',
#  'Edwin_Hutchins.txt',
#  'Edwin_Mansfield.txt',
#  'Edwin_R._A._Seligman.txt',
#  'Edwin_Ray_Guthrie.txt',
#  'Edwin_Sutherland.txt',
#  'Ed_Diener.txt',
#  'Ehud_Kalai.txt',
#  'Eileen_Barker.txt',
#  'Eileen_Hunt_Botting.txt',
#  'Eilert_Sundt.txt',
#  'Ekaterina_Schulmann.txt',
#  'Eleanor_Leacock.txt',
#  'Eleanor_Rosch.txt',
#  'Eleanor_Saffran.txt',
#  'Elgin_Groseclose.txt',
#  'Elhanan_Helpman.txt',
#  'Elias_Canetti.txt',
#  'Eliezer_Jaffe.txt',
#  'Elijah_Anderson.txt',
#  'Elinor_Ostrom.txt',
#  'Eliot_Janeway.txt',
#  'Elisabeth_Altmann-Gottheiner.txt',
#  'Elisabeth_Gidengil.txt',
#  'Elisabeth_Jean_Wood.txt',
#  'Elisabeth_Kübler-Ross.txt',
#  'Elizabeth_Cullen_Dunn.txt',
#  'Elizabeth_Gould_(psychologist).txt',
#  'Elizabeth_Loftus.txt',
#  'Elizabeth_Spelke.txt',
#  'Elizabeth_Zechmeister.txt',
#  'Eliz_Sanasarian.txt',
#  'Eli_Heckscher.txt',
#  'Ella_Cara_Deloria.txt',
#  'Ellen_Langer.txt',
#  'Ellen_Lewin.txt',
#  'Elliot_Turiel.txt',
#  'Ellis_Paul_Torrance.txt',
#  'Elman_Service.txt',
#  'Elmer_Eric_Schattschneider.txt',
#  'Elmer_R._Gates.txt',
#  'Elmira_Bayrasli.txt',
#  'Elsie_Clews_Parsons.txt',
#  'Emanuel_Schegloff.txt',
#  'Emilia_Justyna_Powell.txt',
#  'Emily_Bushnell.txt',
#  'Emily_Greene_Balch.txt',
#  'Emily_Martin_(anthropologist).txt',
#  'Emmanuel_Farhi.txt',
#  'Emmanuel_Saez.txt',
#  'Emma_Lu_Davis.txt',
#  'Endel_Tulving.txt',
#  'Enid_Lakeman.txt',
#  'Enrico_Barone.txt',
#  'Enrico_Ferri_(criminologist).txt',
#  'Enrico_Quarantelli.txt',
#  'Enrique_R._Arzac.txt',
#  'Erich_Fromm.txt',
#  'Erich_Neumann_(psychologist).txt',
#  'Eric_Anderson_(sociologist).txt',
#  'Eric_Dunning.txt',
#  'Eric_Ghysels.txt',
#  'Eric_Hanushek.txt',
#  'Eric_Klinenberg.txt',
#  'Eric_Maskin.txt',
#  'Eric_Roll,_Baron_Roll_of_Ipsden.txt',
#  'Eric_Voegelin.txt',
#  'Eric_Wolf.txt',
#  'Erik_H._Erikson.txt',
#  'Erik_Lindahl.txt',
#  'Erik_Olin_Wright.txt',
#  'Ernesto_de_Martino.txt',
#  'Ernesto_Laclau.txt',
#  'Ernest_Burgess.txt',
#  'Ernest_Gellner.txt',
#  'Ernest_Jones.txt',
#  'Ernst_Angel.txt',
#  'Ernst_Engel.txt',
#  'Ernst_Fehr.txt',
#  'Ernst_Fraenkel_(political_scientist).txt',
#  'Ernst_Heinrich_Weber.txt',
#  'Ernst_Troeltsch.txt',
#  'Erving_Goffman.txt',
#  'Esther_Duflo.txt',
#  'Eszter_Hargittai.txt',
#  'Ethan_Kaplan.txt',
#  'Eugene_Dubois.txt',
#  'Eugene_Fama.txt',
#  'Eugenio_María_de_Hostos.txt',
#  'Eugen_Ehrlich.txt',
#  'Eugen_Rosenstock-Huessy.txt',
#  'Eugen_Slutsky.txt',
#  'Eugen_Varga.txt',
#  'Eugen_von_Böhm-Bawerk.txt',
#  'Eva_Bendix_Petersen.txt',
#  'Eva_Illouz.txt',
#  'Eva_Verbitsky_Hunt.txt',
#  'Eva_Vivalt.txt',
#  'Evelyne_Huber.txt',
#  'Evelyn_Blackwood.txt',
#  'Evelyn_M._Kitagawa.txt',
#  'Everett_Hughes_(sociologist).txt',
#  'Eviatar_Zerubavel.txt',
#  'Evsei_Liberman.txt',
#  'Evsey_Domar.txt',
#  'F._Landa_Jocano.txt',
#  'F._Stuart_Chapin.txt',
#  'F._W._Taussig.txt',
#  'Fabrizio_Saccomanni.txt',
#  'Fabrizio_Zilibotti.txt',
#  'Fahmida_Khatun.txt',
#  'Fareed_Zakaria.txt',
#  'Fatema_Mernissi.txt',
#  'Fathi_Baja.txt',
#  'Fatima_Denton.txt',
#  'Federico_Caffè.txt',
#  'Fei_Xiaotong.txt',
#  'Fei_Xu.txt',
#  'Ferdinand_de_Saussure.txt',
#  'Ferdinand_Tönnies.txt',
#  'Fernando_Alvarez_(economist).txt',
#  'Fernando_Escalante_Gonzalbo.txt',
#  'Fernando_Henrique_Cardoso.txt',
#  'Fernando_Limongi.txt',
#  'Fernando_Vianello.txt',
#  'Fernand_Gobet.txt',
#  'Finn_E._Kydland.txt',
#  'Fischer_Black.txt',
#  'Florence_Connolly_Shipek.txt',
#  'Florence_Goodenough.txt',
#  'Florestan_Fernandes.txt',
#  'Florian_Znaniecki.txt',
#  'Floyd_M._Riddick.txt',
#  'Francesco_Alberoni.txt',
#  'Francesco_Giavazzi.txt',
#  'Frances_Kellor.txt',
#  'France_Winddance_Twine.txt',
#  'Francine_D._Blau.txt',
#  'Francine_Shapiro.txt',
#  'Francisco_Ayala_(novelist).txt',
#  'Francisco_Javier_Carrillo_Gamboa.txt',
#  'Francisco_Varela.txt',
#  'Francis_Beer.txt',
#  'Francis_Fukuyama.txt',
#  'Francis_Galton.txt',
#  'Francis_T._McAndrew.txt',
#  'Francis_William_Newman.txt',
#  'Francis_Ysidro_Edgeworth.txt',
#  'Franco_Modigliani.txt',
#  'Frank-Jürgen_Richter.txt',
#  'Franklin_Allen.txt',
#  'Franklin_Henry_Giddings.txt',
#  'Frank_Baumgartner.txt',
#  'Frank_D._Bean.txt',
#  'Frank_Hamilton_Cushing.txt',
#  'Frank_J._Chaloupka.txt',
#  'Frank_Knight.txt',
#  'Frank_Lancaster_Jones.txt',
#  'Frank_Ramsey_(mathematician).txt',
#  'Frank_Webster_(sociologist).txt',
#  'Frantz_Fanon.txt',
#  'Franz_Boas.txt',
#  'Franz_Brentano.txt',
#  'Franz_Neumann_(political_scientist).txt',
#  'Franz_Oppenheimer.txt',
#  'François_de_Singly.txt',
#  'François_Quesnay.txt',
#  'François_Simiand.txt',
#  'Frederick_B._Lindstrom.txt',
#  'Frederic_Bartlett.txt',
#  'Frederic_Mishkin.txt',
#  'Frederic_Sterling_Lee.txt',
#  'Fredric_Jameson.txt',
#  'Fredrik_Barth.txt',
#  'Fred_M._Taylor.txt',
#  'Friedrich_Engels.txt',
#  'Friedrich_Hayek.txt',
#  'Friedrich_List.txt',
#  'Friedrich_Pollock.txt',
#  'Fritz_Perls.txt',
#  'Fritz_Strack.txt',
#  'Frédéric_Bastiat.txt',
#  'Frédéric_Lordon.txt',
#  'Frédéric_Passy.txt',
#  'Félix_Guattari.txt',
#  'G._L._S._Shackle.txt',
#  'G._S._Ghurye.txt',
#  'G._Stanley_Hall.txt',
#  'G._William_Domhoff.txt',
#  'Gabriele_Klein.txt',
#  'Gabriel_Almond.txt',
#  'Gabriel_Tarde.txt',
#  'Gad_Barzilai.txt',
#  'Gaetano_Mosca.txt',
#  'Gail_Jefferson.txt',
#  'Gail_Omvedt.txt',
#  'Gananath_Obeyesekere.txt',
#  'Gardiner_Means.txt',
#  'Garry_Runciman,_3rd_Viscount_Runciman_of_Doxford.txt',
#  'Gary_A._Klein.txt',
#  'Gary_Alan_Fine.txt',
#  'Gary_Becker.txt',
#  'Gary_Gorton.txt',
#  'Gary_Jacobson.txt',
#  'Gary_King_(political_scientist).txt',
#  'Gary_T._Marx.txt',
#  'Gar_Alperovitz.txt',
#  'Gavin_Wright.txt',
#  'Gawdat_Bahgat.txt',
#  'Gayle_Rubin.txt',
#  'Gene_Grossman.txt',
#  'Gene_Sperling.txt',
#  'Geoffrey_Beattie.txt',
#  'George-Marios_Angeletos.txt',
#  'Georges_Anderla.txt',
#  'Georges_Balandier.txt',
#  'Georges_Canguilhem.txt',
#  'Georges_Davy.txt',
#  'Georges_Friedmann.txt',
#  'Georges_Gurvitch.txt',
#  'Georges_Sorel.txt',
#  'George_A._Lundberg.txt',
#  'George_Akerlof.txt',
#  'George_Albee.txt',
#  'George_Armitage_Miller.txt',
#  'George_Ayittey.txt',
#  'George_C._Homans.txt',
#  'George_Catlin_(political_scientist).txt',
#  'George_Dantzig.txt',
#  'George_E._Marcus.txt',
#  'George_Edgar_Vincent.txt',
#  'George_Gilder.txt',
#  'George_Goodman.txt',
#  'George_Grantham_(economic_historian).txt',
#  'George_Herbert_Mead.txt',
#  'George_J._Borjas.txt',
#  'George_Kelly_(psychologist).txt',
#  'George_Lakoff.txt',
#  'George_M._Stratton.txt',
#  'George_Mandler.txt',
#  'George_Michael_(professor).txt',
#  'George_Murdock.txt',
#  'George_Reisman.txt',
#  'George_Ritzer.txt',
#  'George_Steinmetz_(academic).txt',
#  'George_Trumbull_Ladd.txt',
#  'George_Tsebelis.txt',
#  'George_W._Stocking_Sr..txt',
#  'Georgina_Waylen.txt',
#  'Georgi_Dimitrov_Dimitrov.txt',
#  'Georg_Elias_Müller.txt',
#  'Georg_Simmel.txt',
#  'Gerald_F._Schroedl.txt',
#  'Gerald_L._Eberlein.txt',
#  'Gerardo_L._Munck.txt',
#  'Gerard_Lyons.txt',
#  'Gerhard_Lenski.txt',
#  'Gershon_Ben-Shakhar.txt',
#  'Gesine_Schwan.txt',
#  'Giancarlo_Pallavicini.txt',
#  'Gianfranco_Pasquino.txt',
#  'Gilberto_Freyre.txt',
#  'Gilles_Deleuze.txt',
#  'Gilles_Lipovetsky.txt',
#  'Gilles_Saint-Paul.txt',
#  'Gillian_Rose.txt',
#  'Giovanni_Arrighi.txt',
#  'Giovanni_Botero.txt',
#  'Giovanni_Sartori.txt',
#  'Gisela_Bleibtreu-Ehrenberg.txt',
#  'Giulio_Angioni.txt',
#  'Giulio_Tremonti.txt',
#  'Glenn_Hubbard_(economist).txt',
#  'Glenn_Wilson_(psychologist).txt',
#  'Gloria_Macapagal_Arroyo.txt',
#  'Gonzalo_Garland.txt',
#  'Gopal_Krishna_Sarangi.txt',
#  'Gordon_Allport.txt',
#  'Gordon_G._Gallup.txt',
#  'Gordon_H._Bower.txt',
#  'Gordon_Tullock.txt',
#  'Gottfried_Haberler.txt',
#  'Graciela_Chichilnisky.txt',
#  'Graham_Allison.txt',
#  'Grayson_L._Kirk.txt',
#  'Gregory_Bateson.txt',
#  'Gregory_Clark_(economist).txt',
#  'Gregory_Forth.txt',
#  'Greg_Mankiw.txt',
#  'Grigorii_Golosov.txt',
#  'Grover_Krantz.txt',
#  'Guido_Tabellini.txt',
#  'Guillermo_Calvo.txt',
#  "Guillermo_O'Donnell.txt",
#  'Gunnar_Myrdal.txt',
#  'Gunter_Schmidt.txt',
#  'Gustave_de_Molinari.txt',
#  'Gustave_Gilbert.txt',
#  'Gustav_Adolf_Wohlgemuth.txt',
#  'Gustav_Cassel.txt',
#  'Gustav_Fechner.txt',
#  'Gustav_Ratzenhofer.txt',
#  'Gustav_von_Schmoller.txt',
#  'Guy_Benton_Johnson.txt',
#  'Guy_Laforest.txt',
#  'Guy_Quaden.txt',
#  'Guy_Standing_(economist).txt',
#  'Gu_Zhun.txt',
#  'György_Lukács.txt',
#  'Gérard_Debreu.txt',
#  'Gérard_Roland_(economist).txt',
#  'Göran_Therborn.txt',
#  'Gøsta_Esping-Andersen.txt',
#  'Günter_Faltin.txt',
#  'Hadley_Arkes.txt',
#  'Halbert_White.txt',
#  'Hal_Varian.txt',
#  'Hank_Wesselman.txt',
#  'Hannah_Arendt.txt',
#  'Hannes_Hólmsteinn_Gissurarson.txt',
#  'Hans-Hermann_Hoppe.txt',
#  'Hans-Jürgen_Walter.txt',
#  'Hans-Werner_Sinn.txt',
#  'Hans_Eysenck.txt',
#  'Hans_Freyer.txt',
#  ...]

# %%
s_ =
